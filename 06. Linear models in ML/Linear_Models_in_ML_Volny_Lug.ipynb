# %% [markdown]
# # Проект: Линейные модели в машинном обучении 🐄

# %% [markdown]
# <h1>СОДЕРДАНИЕ<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Проект:-Линейные-модели-в-машинном-обучении-🐄" data-toc-modified-id="Проект:-Линейные-модели-в-машинном-обучении-🐄-1">Проект: Линейные модели в машинном обучении 🐄</a></span><ul class="toc-item"><li><span><a href="#-Шаг-1.-Загрузим-и-изучим-данные" data-toc-modified-id="-Шаг-1.-Загрузим-и-изучим-данные-1.1"><span style="color: violet"> Шаг 1. Загрузим и изучим данные</span></a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Функция.-Общая-информация-и-Первые-строки" data-toc-modified-id="Функция.-Общая-информация-и-Первые-строки-1.1.0.1">Функция. Общая информация и Первые строки</a></span></li><li><span><a href="#Функция.-Кол-во-дубликатов-и-их-удаление" data-toc-modified-id="Функция.-Кол-во-дубликатов-и-их-удаление-1.1.0.2">Функция. Кол-во дубликатов и их удаление</a></span></li><li><span><a href="#Функция.-Столбчатая-и-Круговая-диаграммы" data-toc-modified-id="Функция.-Столбчатая-и-Круговая-диаграммы-1.1.0.3">Функция. Столбчатая и Круговая диаграммы</a></span></li><li><span><a href="#Функция.-Ящик-с-усами-и-Гистограмма" data-toc-modified-id="Функция.-Ящик-с-усами-и-Гистограмма-1.1.0.4">Функция. Ящик с усами и Гистограмма</a></span></li><li><span><a href="#Функция-phik-корреляций" data-toc-modified-id="Функция-phik-корреляций-1.1.0.5">Функция phik-корреляций</a></span></li><li><span><a href="#Функция.-Диаграммы-рассеяния-с-линиями-тренда" data-toc-modified-id="Функция.-Диаграммы-рассеяния-с-линиями-тренда-1.1.0.6">Функция. Диаграммы рассеяния с линиями тренда</a></span></li><li><span><a href="#Функция.-Расчет-линейной-регрессии" data-toc-modified-id="Функция.-Расчет-линейной-регрессии-1.1.0.7">Функция. Расчет линейной регрессии</a></span></li><li><span><a href="#Функция.-Расчет-метрик-для-каждого-порога" data-toc-modified-id="Функция.-Расчет-метрик-для-каждого-порога-1.1.0.8">Функция. Расчет метрик для каждого порога</a></span></li></ul></li><li><span><a href="#Загрузка-и-изучение-данных" data-toc-modified-id="Загрузка-и-изучение-данных-1.1.1">Загрузка и изучение данных</a></span><ul class="toc-item"><li><span><a href="#Данные-о-стаде-фермера-на-текущий-момент" data-toc-modified-id="Данные-о-стаде-фермера-на-текущий-момент-1.1.1.1">Данные о стаде фермера на текущий момент</a></span></li><li><span><a href="#Данные-об-имени-папы-каждой-коровы-в-стаде-фермера" data-toc-modified-id="Данные-об-имени-папы-каждой-коровы-в-стаде-фермера-1.1.1.2">Данные об имени папы каждой коровы в стаде фермера</a></span></li><li><span><a href="#Данные-о-коровах-«ЭкоФермы»,-которых-фермер-хочет-изучить-перед-покупкой" data-toc-modified-id="Данные-о-коровах-«ЭкоФермы»,-которых-фермер-хочет-изучить-перед-покупкой-1.1.1.3">Данные о коровах «ЭкоФермы», которых фермер хочет изучить перед покупкой</a></span></li></ul></li><li><span><a href="#-Вывод" data-toc-modified-id="-Вывод-1.1.2"><span style="color: violet"> <strong>Вывод</strong></span></a></span></li></ul></li><li><span><a href="#-Шаг-2.-Предобработка-данных" data-toc-modified-id="-Шаг-2.-Предобработка-данных-1.2"><span style="color: violet"> Шаг 2. Предобработка данных</span></a></span><ul class="toc-item"><li><span><a href="#Таблица-ferma_main.-Проверка-на-дубликаты" data-toc-modified-id="Таблица-ferma_main.-Проверка-на-дубликаты-1.2.1">Таблица <code>ferma_main</code>. Проверка на дубликаты</a></span></li><li><span><a href="#Таблица-ferma_dad.-Проверка-на-дубликаты" data-toc-modified-id="Таблица-ferma_dad.-Проверка-на-дубликаты-1.2.2">Таблица <code>ferma_dad</code>. Проверка на дубликаты</a></span></li><li><span><a href="#Таблица-cow_buy.-Проверка-на-дубликаты" data-toc-modified-id="Таблица-cow_buy.-Проверка-на-дубликаты-1.2.3">Таблица <code>cow_buy</code>. Проверка на дубликаты</a></span></li><li><span><a href="#-Вывод" data-toc-modified-id="-Вывод-1.2.4"><span style="color: violet"> <strong>Вывод</strong></span></a></span></li></ul></li><li><span><a href="#-Шаг-3.-Исследовательский-анализ-данных" data-toc-modified-id="-Шаг-3.-Исследовательский-анализ-данных-1.3"><span style="color: violet"> Шаг 3. Исследовательский анализ данных</span></a></span><ul class="toc-item"><li><span><a href="#Статистика-и-графики-распределений-для-категориальных-значений" data-toc-modified-id="Статистика-и-графики-распределений-для-категориальных-значений-1.3.1">Статистика и графики распределений для категориальных значений</a></span><ul class="toc-item"><li><span><a href="#Порода-коровы" data-toc-modified-id="Порода-коровы-1.3.1.1">Порода коровы</a></span></li><li><span><a href="#Тип-пастбища" data-toc-modified-id="Тип-пастбища-1.3.1.2">Тип пастбища</a></span></li><li><span><a href="#Порода-отца-коровы" data-toc-modified-id="Порода-отца-коровы-1.3.1.3">Порода отца коровы</a></span></li><li><span><a href="#Вкус-молока" data-toc-modified-id="Вкус-молока-1.3.1.4">Вкус молока</a></span></li><li><span><a href="#Возраст-коровы" data-toc-modified-id="Возраст-коровы-1.3.1.5">Возраст коровы</a></span></li><li><span><a href="#Имя-отца-коровы" data-toc-modified-id="Имя-отца-коровы-1.3.1.6">Имя отца коровы</a></span></li></ul></li><li><span><a href="#Статистика-и-графики-распределений-для-количественных-значений" data-toc-modified-id="Статистика-и-графики-распределений-для-количественных-значений-1.3.2">Статистика и графики распределений для количественных значений</a></span><ul class="toc-item"><li><span><a href="#Распределение-Удоя" data-toc-modified-id="Распределение-Удоя-1.3.2.1">Распределение <code>Удоя</code></a></span></li><li><span><a href="#Распределение-ЭКЕ" data-toc-modified-id="Распределение-ЭКЕ-1.3.2.2">Распределение <code>ЭКЕ</code></a></span></li><li><span><a href="#Распределение-Сырого-протеина" data-toc-modified-id="Распределение-Сырого-протеина-1.3.2.3">Распределение <code>Сырого протеина</code></a></span></li><li><span><a href="#Распределение-СПО" data-toc-modified-id="Распределение-СПО-1.3.2.4">Распределение <code>СПО</code></a></span></li><li><span><a href="#Распределение--Жиров-в-молоке" data-toc-modified-id="Распределение--Жиров-в-молоке-1.3.2.5">Распределение  <code>Жиров в молоке</code></a></span></li><li><span><a href="#Распределение-Белков-в-молоке" data-toc-modified-id="Распределение-Белков-в-молоке-1.3.2.6">Распределение <code>Белков в молоке</code></a></span></li></ul></li><li><span><a href="#-Вывод" data-toc-modified-id="-Вывод-1.3.3"><span style="color: violet"> <strong>Вывод</strong></span></a></span></li></ul></li><li><span><a href="#-Шаг-4.-Проведём-корреляционный-анализ-признаков-в-датасете" data-toc-modified-id="-Шаг-4.-Проведём-корреляционный-анализ-признаков-в-датасете-1.4"><span style="color: violet"> Шаг 4. Проведём корреляционный анализ признаков в датасете</span></a></span><ul class="toc-item"><li><span><a href="#Изучим-взаимосвязь-между-целевым-и-входными-признаками" data-toc-modified-id="Изучим-взаимосвязь-между-целевым-и-входными-признаками-1.4.1">Изучим взаимосвязь между целевым и входными признаками</a></span></li><li><span><a href="#Построим-диаграммы-рассеяния-с-учетом-категориального-признака" data-toc-modified-id="Построим-диаграммы-рассеяния-с-учетом-категориального-признака-1.4.2">Построим диаграммы рассеяния с учетом категориального признака</a></span><ul class="toc-item"><li><span><a href="#Удой-от-СПО" data-toc-modified-id="Удой-от-СПО-1.4.2.1">Удой от СПО</a></span></li><li><span><a href="#Удой-от-ЭКЕ" data-toc-modified-id="Удой-от-ЭКЕ-1.4.2.2">Удой от ЭКЕ</a></span></li><li><span><a href="#Удой-от-жиров-в-молоке" data-toc-modified-id="Удой-от-жиров-в-молоке-1.4.2.3">Удой от жиров в молоке</a></span></li><li><span><a href="#Удоя-от-сырого-протеина" data-toc-modified-id="Удоя-от-сырого-протеина-1.4.2.4">Удоя от сырого протеина</a></span></li><li><span><a href="#Удой-от-белков" data-toc-modified-id="Удой-от-белков-1.4.2.5">Удой от белков</a></span></li></ul></li><li><span><a href="#--Вывод" data-toc-modified-id="--Вывод-1.4.3"><span style="color: violet">  <strong>Вывод</strong></span></a></span></li></ul></li><li><span><a href="#-Шаг-5.-Обучение-модели-линейной-регрессии" data-toc-modified-id="-Шаг-5.-Обучение-модели-линейной-регрессии-1.5"><span style="color: violet"> Шаг 5. Обучение модели линейной регрессии</span></a></span><ul class="toc-item"><li><span><a href="#Первая-модель" data-toc-modified-id="Первая-модель-1.5.1">Первая модель</a></span><ul class="toc-item"><li><span><a href="#Отбор-признаков-для-модели" data-toc-modified-id="Отбор-признаков-для-модели-1.5.1.1">Отбор признаков для модели</a></span></li></ul></li><li><span><a href="#Вторая-модель" data-toc-modified-id="Вторая-модель-1.5.2">Вторая модель</a></span><ul class="toc-item"><li><span><a href="#Исключим-нелинейность-СПО-и-Удоя" data-toc-modified-id="Исключим-нелинейность-СПО-и-Удоя-1.5.2.1">Исключим нелинейность <code>СПО</code> и <code>Удоя</code></a></span></li><li><span><a href="#Исключим-нелинейность-ЕКЭ-и-Удоя" data-toc-modified-id="Исключим-нелинейность-ЕКЭ-и-Удоя-1.5.2.2">Исключим нелинейность <code>ЕКЭ</code> и <code>Удоя</code></a></span></li><li><span><a href="#Создадим-вторую-модель" data-toc-modified-id="Создадим-вторую-модель-1.5.2.3">Создадим вторую модель</a></span></li></ul></li><li><span><a href="#Третья-модель" data-toc-modified-id="Третья-модель-1.5.3">Третья модель</a></span><ul class="toc-item"><li><span><a href="#Добавим-новый-признак-и-избавимся-от-нелинейности-признаков" data-toc-modified-id="Добавим-новый-признак-и-избавимся-от-нелинейности-признаков-1.5.3.1">Добавим новый признак и избавимся от нелинейности признаков</a></span></li><li><span><a href="#Создадим-третью-модель" data-toc-modified-id="Создадим-третью-модель-1.5.3.2">Создадим третью модель</a></span></li></ul></li><li><span><a href="#Сравнение-качества-трёх-моделей-линейной-регрессии" data-toc-modified-id="Сравнение-качества-трёх-моделей-линейной-регрессии-1.5.4">Сравнение качества трёх моделей линейной регрессии</a></span></li><li><span><a href="#Оценка-качества-каждой-модели-по-трём-метрикам" data-toc-modified-id="Оценка-качества-каждой-модели-по-трём-метрикам-1.5.5">Оценка качества каждой модели по трём метрикам</a></span></li><li><span><a href="#Прогноз-Удоя-коров-&quot;ЭкоФермы&quot;" data-toc-modified-id="Прогноз-Удоя-коров-&quot;ЭкоФермы&quot;-1.5.6">Прогноз Удоя коров "ЭкоФермы"</a></span></li><li><span><a href="#--Вывод" data-toc-modified-id="--Вывод-1.5.7"><span style="color: violet">  <strong>Вывод</strong></span></a></span></li></ul></li><li><span><a href="#-Шаг-6.-Обучение-модели-логистической-регрессии" data-toc-modified-id="-Шаг-6.-Обучение-модели-логистической-регрессии-1.6"><span style="color: violet"> Шаг 6. Обучение модели логистической регрессии</span></a></span><ul class="toc-item"><li><span><a href="#Подготовим-данные-и-обучим-на-них-модель-логистической-регрессии" data-toc-modified-id="Подготовим-данные-и-обучим-на-них-модель-логистической-регрессии-1.6.1">Подготовим данные и обучим на них модель логистической регрессии</a></span></li><li><span><a href="#Проанализируем-модель-логистической-регрессии" data-toc-modified-id="Проанализируем-модель-логистической-регрессии-1.6.2">Проанализируем модель логистической регрессии</a></span></li><li><span><a href="#Прогноз-Вкуса-молока-коров-&quot;ЭкоФермы&quot;" data-toc-modified-id="Прогноз-Вкуса-молока-коров-&quot;ЭкоФермы&quot;-1.6.3">Прогноз Вкуса молока коров "ЭкоФермы"</a></span></li><li><span><a href="#--Вывод" data-toc-modified-id="--Вывод-1.6.4"><span style="color: violet">  <strong>Вывод</strong></span></a></span></li></ul></li><li><span><a href="#-Итоговые-выводы" data-toc-modified-id="-Итоговые-выводы-1.7"><span style="color: violet"> Итоговые выводы</span></a></span></li></ul></li></ul></div>

# %% [markdown]
# <div style="background-color: white; border: 3px solid black; border-radius: 10px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# **Заказчик:** Фермер, владелец молочного хозяйства «Вольный луг».
#
# **Цель:** Разработать модель машинного обучения для минимизации рисков при закупке коров и обеспечения планового развития молочного хозяйства «Вольный луг».
#
# **Задачи:**
#
# *Создать две прогнозные модели для отбора бурёнок в поголовье.*
# - Первая будет прогнозировать возможный удой коровы (целевой признак `Удой`);
# - Вторая — рассчитывать вероятность получить вкусное молоко от коровы (целевой признак `Вкус молока`).
#
# *Критерии* отбора коров.
# - средний удой за год — не менее 6000 килограммов;
# - молоко должно быть вкусным.
#
# ---
#
# **Описание данных:**
#
# <span style="color:violet">1. Таблица  `ferma_main` [содержит информацию **о стаде фермера на текущий момент**]
#
# - `id` — уникальный идентификатор коровы.
# - `Удой, кг` — масса молока, которую корова даёт в год (в килограммах).
# - `ЭКЕ` (Энергетическая кормовая единица) — показатель питательности корма коровы.
# - `Сырой протеин, г` — содержание сырого протеина в корме (в граммах).
# - `СПО` (Сахаро-протеиновое соотношение) — отношение сахара к протеину в корме коровы.
# - `Порода` — порода коровы.
# - `Тип пастбища` — ландшафт лугов, на которых паслась корова.
# - `порода папы_быка` — порода папы коровы.
# - `Жирность,%` — содержание жиров в молоке (в процентах).
# - `Белок,%` — содержание белков в молоке (в процентах).
# - `Вкус молока` — оценка вкуса по личным критериям фермера, бинарный признак (вкусно, не вкусно).
# - `Возраст` — возраст коровы, бинарный признак (менее_2_лет, более_2_лет).
#
# **Признаки** в датасете `ferma_main` можно разделить на группы [взаимосвясь признаков в датасете]
#
# - *Характеристики коровы:* id, Порода, порода папы_быка, Возраст.
# - *Характеристики корма:* ЭКЕ (Энергетическая кормовая единица), Сырой протеин, г, СПО (Сахаро-протеиновое соотношение).
# - *Характеристика пастбища:* Тип пастбища.
# - *Характеристики молока:* Удой, кг, Жирность,%, Белок,%, Вкус молока.
#
# <span style="color:violet">2. Таблица  `ferma_dad` [содержит информацию **об имени папы каждой коровы в стаде фермера**]
#
# - `id` — уникальный идентификатор коровы.
# - `Имя Папы` — имя папы коровы.
#
# <span style="color:violet">3. Таблица  `cow_buy` [содержит информацию **о коровах «ЭкоФермы», которых фермер хочет изучить перед покупкой**]
#
# - `Порода` — порода коровы.
# - `Тип пастбища` — ландшафт лугов, на которых паслась корова.
# - `порода папы_быка` — порода папы коровы.
# - `Имя_папы` — имя папы коровы.
# - `Текущая_жирность,%` — содержание жиров в молоке (в процентах).
# - `Текущий_уровень_белок,%` — содержание белков в молоке (в процентах).
# - `Возраст` — возраст коровы, бинарный признак (менее 2 лет / более 2 лет).
#
# **Особенности** датасета `cow_buy`
#
# - Содержание белков и жиров в молоке указано на момент продажи — когда «ЭкоФерма» давала коровам свой корм.
# - Параметры корма `ЭКЕ (Энергетическая кормовая единица), Сырой протеин, г` и `СПО (Сахаро-протеиновое соотношение)` отсутствуют. Технологи заказчика пересмотрели подход к кормлению: для новых коров планируется увеличить значения каждого из этих параметров на 5%.
# - Кроме того, отсутствуют признаки `Удой, кг` и `Вкус молока`. Это целевые признаки, именно их предстоит предсказать!

# %% [markdown]
# ## <span style="color:violet"> Шаг 1. Загрузим и изучим данные

# %%
# !pip install -q phik
# Необходимые импорты
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import phik

from scipy import stats as st

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import (r2_score, 
                             mean_squared_error, 
                             mean_absolute_error, 
                             accuracy_score, 
                             recall_score, 
                             precision_score,
                             precision_recall_curve,
                             confusion_matrix 
                            )

# %% [markdown]
# #### Функция. Общая информация и Первые строки

# %%
def head_and_info_display(df, n=5, show_shape=True, show_dtypes=True):
    '''
    Параметры:
    df - DataFrame для анализа
    n - Количество строк
    '''
    print('~' * 23)
    print('ИНФОРМАЦИЯ О ДАТАФРЕЙМЕ')
    print('~' * 23)
   
    print(f'Форма данных: {df.shape[0]} строк, {df.shape[1]} столбцов')
    
    print(f"\nПервые {n} строк:")
    print("-" * 15)
    display(df.head(n))
    
    print(f"\nОбщая информация:")
    print("-" * 17)
    df.info()

# %% [markdown]
# #### Функция. Кол-во дубликатов и их удаление

# %%
def cnt_and_drop_duplicates(df):
    
    '''Отображает кол-во дублей и удаляет их, если они есть'''
    
    duplicated = df.duplicated().sum()
    print(f'Кол-во дублей ДО: {duplicated}')
    print(f'Кол-во строк ДО: {df.shape[0]}')
    if duplicated > 0:
        df = df.drop_duplicates()
        duplicated = df.duplicated().sum()
        print(f'Кол-во дублей ПОСЛЕ: {duplicated}')
        print(f'Кол-во строк ПОСЛЕ: {df.shape[0]}')

# %% [markdown]
# #### Функция. Столбчатая и Круговая диаграммы

# %%
# Функция для быстрого отображения категориальных признаков с двумя графиками и симпатичной цветовой палитрой
def plot_categorical(df, column, figsize=(15, 8), palette='Accent'):
    
    '''Столбчатая и круговая диаграмма для категориальных признаков'''
    
    # Подсчитываем кол-во уникальных значений
    value_counts = df[column].value_counts()
    
    # Создаем две диаграммы
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, # 1 ряд, 2 графика в ряд
                                   figsize=figsize)
    # fig управляет всей областью отрисовки
    # ax1 - левый график (первый столбец)
    # ax2 - правый график (второй столбец)  
    
    # 1. Столбчатая диаграмма
    sns.countplot(data=df, # Указываем, откуда брать данные для построения графика
                  x=column, # Указываем, какой столбец использовать для оси X
                  palette=palette, # Задаем цветовую схему для столбцов
                  ax=ax1 # Указываем, в какой области рисовать график
                  )
    ax1.set_title(f'Распределение по {column}', fontsize=14)
    ax1.set_xlabel(column) #Подпись дляя оси х на графике ах1
    ax1.set_ylabel('Кол-во')
    
    # Добавляем числа на столбцы
    for p in ax1.patches: # Цикл по каждому столбцу на графике
        ax1.annotate(f'{p.get_height()}', #добавляем текстовую аннотацию на график
                    (p.get_x() + p.get_width()/2, p.get_height()),
                    ha='center',# Горизонтальное выравнивание по центру
                    va='bottom', # Вертикальное выравнивание по низу (текст над столбцом)
                    fontweight='bold')
    #p.get_x() - координата X левого края столбца
    #get_width()/2 - половина ширины столбца
    #p.get_height() - координата Y верхнего края столбца
    
    # 2. Круговая диаграмма
    colors = sns.color_palette(palette, 
                               len(value_counts)#количество цветов (по числу категорий)
                               )
    ax2.pie(value_counts.values,#кол-во
            labels=value_counts.index,#название категорий 
            autopct='%1.1f%%', #отображение процентов
            colors=colors, #цвета секторов
            startangle=90) #начальный угол
    ax2.set_title(f'Доли категорий {column}', 
                  fontsize=14)
    
    print(f"Статистика для '{column}':")
    print(f"Всего записей: {len(df)}")
    print(f"Уникальных категорий: {df[column].nunique()}")
    print(f"Самая частая категория: '{value_counts.index[0]}' ({value_counts.iloc[0]} записей)")
    print(f"Доля самой частой категории: {value_counts.iloc[0]/len(df)*100:.1f}%")

# %% [markdown]
# #### Функция. Ящик с усами и Гистограмма

# %%
# Функция для быстрого отображения количественных признаков с двумя графиками и симпатичной цветовой палитрой
def plot_quantitative(df, column, figsize=(15, 6), palette='Paired',
                     boxplot_title=None, boxplot_ylabel=None,
                     hist_title=None, hist_xlabel=None, hist_ylabel=None): 
    
    ''' Ящик с усами и Гистограмма для количественных признаков'''
    
    # Создаем две диаграммы
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, # 1 ряд, 2 графика в ряд
                                   figsize=figsize)
    # fig управляет всей областью отрисовки
    # ax1 - левый график (первый столбец)
    # ax2 - правый график (второй столбец)
    
    # Цвет для графиков
    color = sns.color_palette(palette, 1)[0]
    
    # 1. Ящик с усами
    sns.boxplot(data=df, 
                y=column, # Указываем, какой столбец использовать для оси Y
                color=color, # Задаем цвет
                ax=ax1 # Указываем, в какой области рисовать график
                )
    
    # Устанавливаем заголовок и подписи для ящика с усами
    boxplot_title = boxplot_title or f'Ящик с усами: {column}'
    boxplot_ylabel = boxplot_ylabel or column
    
    ax1.set_title(boxplot_title, fontsize=14)
    ax1.set_ylabel(boxplot_ylabel) # Подпись для оси Y на графике ax1
    
    # 2. Гистограмма с KDE
    sns.histplot(data=df, 
                 x=column, # Указываем, какой столбец использовать для оси X
                 kde=True, # Добавляем линию плотности
                 color=color, # Задаем цвет
                 ax=ax2 # Указываем, в какой области рисовать график
                 )
    
    # Устанавливаем заголовок и подписи для гистограммы
    hist_title = hist_title or f'Гистограмма: {column}'
    hist_xlabel = hist_xlabel or column
    hist_ylabel = hist_ylabel or 'Частота'
    
    ax2.set_title(hist_title, fontsize=14)
    ax2.set_xlabel(hist_xlabel) # Подпись для оси X на графике ax2
    ax2.set_ylabel(hist_ylabel)
    
    # Добавляем линию медианы на гистограмму
    median_val = df[column].median()
    ax2.axvline(median_val, color='red', linestyle='--', 
                label=f'Медиана: {median_val:.3f}')
    ax2.legend()
    
    plt.tight_layout()
    plt.show()
    
    # Вывод статистики с использованием describe()
    print(f"Статистика для '{column}':")
    stats = df[column].describe()
    print(f"Кол-во записей: {stats['count']:.0f}")
    print(f"Среднее: {stats['mean']:.3f}")
    print(f"Стандартное отклонение: {stats['std']:.3f}")
    print(f"Медиана: {stats['50%']:.3f}")
    print(f"Минимум: {stats['min']:.3f}")
    print(f"Максимум: {stats['max']:.3f}")
    print(f"25-й перцентиль: {stats['25%']:.3f}")
    print(f"75-й перцентиль: {stats['75%']:.3f}")

# %% [markdown]
# #### Функция phik-корреляций

# %%
# Функция построяния тепловой карты phik-корреляций
def quick_phik_analysis(df, target=None):
    '''
    Функция phik-корреляций
    '''
    df_temp = df.copy()# Создаем копию чтобы не менять исходный DataFrame 
    df_temp = df_temp.drop('id', axis=1, errors='ignore')# Дропаем ненужные признаки
    # Явно указываем числовые колонки для interval_cols
    numeric_cols = df_temp.select_dtypes(include=[np.number]).columns.tolist()   
    # Phik-матрица для всех признаков с явным указанием interval_cols
    phik_matrix = df_temp.phik_matrix(interval_cols=numeric_cols).round(3)
    
    # Визуализация
    plt.figure(figsize=(12, 10))
    sns.heatmap(phik_matrix, annot=True, cmap='coolwarm', center=0.5, fmt='.2f')
    plt.title('Phik-корреляции всех признаков')
    plt.tight_layout()
    plt.show()
    
    #return phik_matrix

# %% [markdown]
# #### Функция. Диаграммы рассеяния с линиями тренда

# %%
def plot_multiple_scatter_trends_with_phik(df, quant_column, categ_columns=None, target_column='milk_kg', figsize=(15, 10)):
    
    '''
    Строит диаграммы рассеяния с линиями тренда и показывает phik-корреляцию
    
    Параметры:
    df - DataFrame с данными
    quant_column - Количественный признак (например, 'eke', 'protein_g')
    categ_columns - Список категориальных признаков
    target_column - Целевой признак (по умолчанию 'milk_kg' - удой)
    figsize - Размер общего графика
    
    '''
    
    # Вычисляем phik-корреляцию для всех признаков (матрица 2х2)
    phik_corr = df[[quant_column, target_column]].phik_matrix().iloc[0, 1]
    
    # Категории по умолчанию. Если категориальные признаки не указаны, используем все доступные из нашего датасета
    if categ_columns is None:
        categ_columns = ['breed_cow', # Порода коровы
                         'type_pasture', # Тип пастбища (холмистое, равнинное)
                         'breed_dad_cow',# Порода отца коровы (быка)
                         'taste_milk', # Вкус молока (вкусное/не вкусное)
                         'age' # Возраст коровы
                        ]
    
    # Создаем сетку графиков (Вычисляем количество строк и столбцов для subplots)
    n_plots = len(categ_columns)#Кол-во графиков = кол-во категориальных признаков
    n_cols = 2 # Фиксируем 2 столбца (всегда по 2 графика в строке)
    n_rows = (n_plots + 1) // n_cols  # Вычисляем сколько строк нужно (округляем вверх, чтобы все графики поместились)
    
    # Создаем сетку графиков и подготавливаем оси для удобной работы
    fig, axes = plt.subplots(n_rows, n_cols, figsize=figsize)#создаем фигуру и оси для всех графиков
    if hasattr(axes, 'flatten'): # Проверяем, является ли axes numpy массивом
        axes = axes.flatten() # Преобразуем двумерный массив в плоский одномерный
                              # Пример: [[ax1, ax2], [ax3, ax4]] → [ax1, ax2, ax3, ax4]
    elif n_cols == 1: # Если это не numpy массив, проверяем количество столбцов
        axes = [axes] # Случай одного столбца (несколько графиков в одном столбце)
                      # Оборачиваем в список, чтобы иметь единообразный интерфейс
    else:
        axes = axes # Все остальные случаи (обычно одна строка с несколькими столбцами)
                    # Например: plt.subplots(1, 2) уже возвращает список [ax1, ax2]
                    # Оставляем как есть, так как это уже плоский список
    
    # Строим графики
    for i, categ_column in enumerate(categ_columns):
        if i >= len(axes): #защита от выхода за границы массива
            break       
        ax = axes[i]
        
        # Рисуем основной точечный график
        sns.scatterplot(data=df, 
                        x=quant_column, #по оси х
                        y=target_column,#по оси y
                        hue=categ_column,# цвет точек по категориям
                        alpha=0.7, # полупрозрачность, чтобы видеть перекрывающиеся точки
                        palette='Set2', 
                        ax=ax, 
                        s=60) # размер точек
        
        # Линии тренда
        # Для каждой уникальной категории фильтруем данные
        unique_categories = df[categ_column].unique()
        colors = sns.color_palette('Dark2', len(unique_categories))
        
        for color_idx, category in enumerate(unique_categories):  #получает все значения категории
            cat_data = df[df[categ_column] == category] # оставляет только строки этой категории
        
            # Строим линию тренда для каждой категории
            if len(cat_data) > 1: #проверка, что есть хотя бы 2 точки (иначе тренд не построить)
                slope, intercept = np.polyfit(cat_data[quant_column], cat_data[target_column], 1) # Линейная регрессия (прямая линия)
                x_range = np.linspace(cat_data[quant_column].min(), cat_data[quant_column].max(), 100) #создаем 100 точек для плавной линии
                y_trend = slope * x_range + intercept #вычисляем значения по уравнению прямой
       
                # Рисуем линию тренда на графике        
                ax.plot(x_range, 
                        y_trend, 
                        linewidth=3, #толстая линия, её хорошо видно
                        color=colors[color_idx])  #берем цвет из палитры, соответствующий категории
            
        # Оформляем график(заголовок, легенда, сетка)
        ax.set_title(f'Удой vs {quant_column} по {categ_column}', fontsize=12, fontweight='bold')
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
        ax.grid(True, alpha=0.3)
        
        # Добавляем в угол графика phik-корреляцию
        ax.text(0.05, 0.95, # позиция в левом верхнем углу (5% слева, 95% сверху)
                f'Phik: {phik_corr:.3f}',  # Phik-корреляция
                transform=ax.transAxes, #координаты относительно графика (0-1)
                fontsize=10,
                bbox=dict(boxstyle='round', facecolor='white', alpha=0.8)#белая подложка с прозрачностью
               )
    
    # Скрываем пустые графики в сетке
    for j in range(i + 1, len(axes)):#Если графиков меньше чем ячеек в сетке (например, 3 графика в сетке 2×2), скрываем 4-ю пустую ячейку
        axes[j].set_visible(False)
    
    # Заголовок и отображение
    plt.suptitle(f'ЗАВИСИМОСТЬ УДОЯ ОТ {quant_column} С УЧЕТОМ КАТЕГОРИИ\nPhik-корреляция: {phik_corr:.3f}', 
                 fontsize=16, 
                 fontweight='bold')# общий заголовок для всей сетки
    plt.tight_layout()#автоматически подгоняет расстояния между графиками
    plt.show()
    
    # Выводим общую статистику
    print(f'Phik-корреляция: {phik_corr:.3f}')

# %% [markdown]
# #### Функция. Расчет линейной регрессии

# %%
df_metr_storage = pd.DataFrame(columns=['name_model', 'R2', 'MSE', 'RMSE', 'MAE']) 

def func_linear_regression_model(df, name, list_1, list_2, name_model):
  
    global df_metr_storage
    
    RANDOM_STATE = 42

    X = df.drop(name, axis=1)
    y = df[name]
    
    # Разобьем данные на выборки
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=RANDOM_STATE)
    

    # Кодируем категориальные признаки
    encoder = OneHotEncoder(drop='first', sparse=False)
    X_train_ohe = encoder.fit_transform(X_train[list_1])
    X_test_ohe = encoder.transform(X_test[list_1])
    encoder_col_names = encoder.get_feature_names()

    #  Масштабируем количественные признаки
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train[list_2])
    X_test_scaled = scaler.transform(X_test[list_2])

    # Cоздаём тренировочный и тестовый датафреймы из закодированных и отмасштабированных данных
    X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)
    X_test_ohe = pd.DataFrame(X_test_ohe, columns=encoder_col_names)

    X_train_scaled = pd.DataFrame(X_train_scaled, columns=list_2)
    X_test_scaled = pd.DataFrame(X_test_scaled, columns=list_2)

    #объединяем все преобразованные данные в тренировочный и тестовый датафреймы
    #и сбрасываем индексы в датафрейме с числовыми индексами, чтобы избежать ошибок
    X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1).reset_index(drop=True)
    X_test = pd.concat([X_test_ohe, X_test_scaled], axis=1).reset_index(drop=True)
    
    # Создадим модельлинейной регрессии и получим прогноз
    model_lr = LinearRegression()# инициализируем модель линейной регрессии
    model_lr.fit(X_train, y_train)# обучим модель на тренировочных данных
    predictions = model_lr.predict(X_test) #получим предсказания модели на валидационной данных 

    #Остатки
    residuals = y_test - predictions
    
    # Оценим качество модели на валидационной выборке

    R2 = r2_score(y_test, predictions) # Коэффициент детерминации
    MSE = mean_squared_error(y_test, predictions)#Средняя квадратичная ошибка
    RMSE = mean_squared_error(y_test, predictions, squared=False)#Среднеквадратичное отклонение
    MAE = mean_absolute_error(y_test, predictions)#Средняя абсолютная ошибка
    mean = residuals.mean()
    std = residuals.std()

    metr = {'name_model': name_model, 'R2': R2, 'MSE': MSE, 'RMSE': RMSE, 'MAE': MAE, 'Среднее остатков': mean, 
            'Стандартное отклонение': std}
    df_metr_storage = df_metr_storage.append(metr, ignore_index=True)

    # Создаем визуализацию
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    # Гистограмма распределения остатков
    axes[0].hist(residuals, bins=30, color='#4CAF50', alpha=0.7, edgecolor='white', linewidth=0.5)
    axes[0].axvline(x=0, color='#FF6B6B', linestyle='--', linewidth=2, label='Cредняя сумма остатков')
    axes[0].axvline(x=residuals.median(), color='#FFA726', linestyle='--', linewidth=2, label=f'Среднее: {residuals.mean():.2f}')
    axes[0].set_xlabel('Остатки', fontsize=12)
    axes[0].set_ylabel('Частота', fontsize=12)
    axes[0].set_title('Гистограмма распределения остатков', fontsize=14)
    axes[0].legend()
    axes[0].grid(alpha=0.3)

    # График зависимости остатков от предсказаний
    scatter = axes[1].scatter(predictions, residuals, alpha=0.6, color='#2196F3', s=50)
    axes[1].axhline(y=0, color='#FF6B6B', linestyle='--', linewidth=2, label='Cредняя сумма остатков')
    axes[1].set_xlabel('Предсказанные значения', fontsize=12)
    axes[1].set_ylabel('Остатки', fontsize=12)
    axes[1].set_title('Остатки vs Предсказания', fontsize=14)
    axes[1].legend()
    axes[1].grid(alpha=0.3)

    # Добавляем общую статистику
    stats_text = f'Статистика остатков:\nСреднее: {residuals.mean():.2f}\nМедиана: {residuals.median():.2f}\nСтд: {residuals.std():.2f}'
    fig.text(0.02, 0.02, stats_text, fontsize=10, bbox=dict(boxstyle="round,pad=0.3", facecolor="lightpink"))

    plt.tight_layout()
    plt.show()

    # Дополнительная информация
    print(f"R2_score: {R2:.2f}")
    print(f"Среднее остатков: {residuals.mean():.2f}")
    print(f"Медиана остатков: {residuals.median():.2f}")
    print(f"Стандартное отклонение: {residuals.std():.2f}")
    print(f"Минимальный остаток: {residuals.min():.2f}")
    print(f"Максимальный остаток: {residuals.max():.2f}")
    
    return (residuals, X, y, predictions, (X_train_ohe, X_test_ohe), (X_train_scaled, X_test_scaled), model_lr)

# %% [markdown]
# #### Функция. Расчет метрик для каждого порога

# %%
def choice_threshold(threshold_list, proba_df):
    # Создаем пустой DataFrame для результатов с указанными колонками
    result_df = pd.DataFrame(columns=['Порог', 'Precision', 'Recall', 'Количество FP', 
                                      'Число предсказанных объектов', 'Всего объектов класса 1'])

    # Перебираем каждый порог из списка
    for threshold in threshold_list:
        # Создаем имя колонки для предсказаний с текущим порогом
        column_name = 'y_pred_' + str(threshold)

            # Precision: среднее значение реальных меток среди предсказанных как класс 1
        precision = proba_df.loc[proba_df[column_name] == 1, 'y_test_lgr'].mean()
            # Число предсказанных объектов: сколько всего объектов отнесено к классу 1
        predicted_objects = proba_df[column_name].sum()
            # Всего объектов класса 1: сколько реально объектов класса 1 в данных
        total_objects_class_1 = proba_df['y_test_lgr'].sum()
            # Recall: доля правильно найденных объектов класса 1 от общего их числа
        recall = proba_df.loc[(proba_df[column_name] == 1) & (proba_df['y_test_lgr'] == 1)].shape[0] / total_objects_class_1

        # Количество ложноположительных предсказаний (FP): предсказали 1, а реально 0
        false_positives = proba_df.loc[(proba_df[column_name] == 1) & (proba_df['y_test_lgr'] == 0)].shape[0]

        # Создаем новую строку как отдельный DataFrame
        row_new = pd.DataFrame({ #создаем новый маленький DataFrame
            'Порог': [threshold], #[значение] - создание списка с одним элементом.Т.к. DataFrame ожидает списки значений для колонок
            'Precision': [precision],
            'Recall': [recall],
            'Количество FP': [false_positives],
            'Число предсказанных объектов': [predicted_objects],#кол-во случаев, для которых модель сделала предсказание класс 1
            'Всего объектов класса 1': [total_objects_class_1], #общее кол-во элементов, которое относятся к «класс 1».
        })
        
        # Объединяем с основным DataFrame
        result_df = pd.concat([result_df, row_new], ignore_index=True)

    return result_df

# %% [markdown]
# ### Загрузка и изучение данных

# %%
# Прочитаем файл с данными и сохраненим в датафреймы
ferma_main = pd.read_csv('/datasets/ferma_main.csv', sep=';', decimal=',')
ferma_dad = pd.read_csv('/datasets/ferma_dad.csv', sep=';')
cow_buy = pd.read_csv('/datasets/cow_buy.csv', sep=';', decimal=',')

# %%
# Создадим словарь для удобства замены названий колонок на соответствующие допустимому стилю
rename_columns = {
                    'Удой, кг': 'milk_kg',
                    'ЭКЕ (Энергетическая кормовая единица)': 'eke',
                    'Сырой протеин, г': 'protein_g',
                    'СПО (Сахаро-протеиновое соотношение)': 'spo',
                    'Порода': 'breed_cow',
                    'Тип пастбища': 'type_pasture',
                    'порода папы_быка': 'breed_dad_cow',
                    'Жирность,%': 'fat_content_percent',
                    'Белок,%': 'protein_percent',
                    'Вкус молока': 'taste_milk',
                    'Возраст': 'age',
                    'Имя Папы': 'dad_name',
                    'Имя_папы': 'dad_name',
                    'Текущая_жирность,%': 'current_fat_content_percent',
                    'Текущий_уровень_белок,%': 'current_protein_percent',
                  }
# Переименовываем столбцы
ferma_main.rename(columns=rename_columns, inplace=True)
ferma_dad.rename(columns=rename_columns, inplace=True)
cow_buy.rename(columns=rename_columns, inplace=True)

# %% [markdown]
# #### Данные о стаде фермера на текущий момент

# %%
# 1. Выведем информацию о датафрейме 'ferma_main'
head_and_info_display(ferma_main)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~
# ИНФОРМАЦИЯ О ДАТАФРЕЙМЕ
# ~~~~~~~~~~~~~~~~~~~~~~~
# Форма данных: 634 строк, 12 столбцов
#
# Первые 5 строк:
# ---------------
#    id  milk_kg   eke  protein_g    spo        breed_cow type_pasture  \
# 0   1     5863  14.2       1743  0.890   Вис Бик Айдиал    Равнинное
# 1   2     5529  12.8       2138  0.890   Вис Бик Айдиал    Равнинные
# 2   3     5810  14.0       1854  0.885  РефлешнСоверинг    Холмистое
# 3   4     5895  12.4       2012  0.885  РефлешнСоверинг    Холмистое
# 4   5     5302  12.8       1675  0.885   Вис Бик Айдиал    Равнинные
#
#   breed_dad_cow  fat_content_percent  protein_percent taste_milk          age
# 0        Айдиал                 3.58            3.076     вкусно  более_2_лет
# 1       Соверин                 3.54            3.079     вкусно  менее_2_лет
# 2       Соверин                 3.59            3.074  не вкусно  более_2_лет
# 3        Айдиал                 3.40            3.075  не вкусно  более_2_лет
# ...

# %%
# Приведём к строчным буквам значения в столбце type_pasture таблицы ferma_main
ferma_main['type_pasture'] = ferma_main['type_pasture'].str.lower()

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# В таблице `ferma_main` 634 записи.
# На первый взгляд данные чистенькие - нет пропусков в данных, типы данных верные.

# %% [markdown]
# #### Данные об имени папы каждой коровы в стаде фермера

# %%
# 2. Выведем информацию о датафрейме 'ferma_dad'
head_and_info_display(ferma_dad)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~
# ИНФОРМАЦИЯ О ДАТАФРЕЙМЕ
# ~~~~~~~~~~~~~~~~~~~~~~~
# Форма данных: 629 строк, 2 столбцов
#
# Первые 5 строк:
# ---------------
#    id  dad_name
# 0   1    Буйный
# 1   2  Соловчик
# 2   3     Барин
# 3   4    Буйный
# 4   5     Барин
# Общая информация:
# -----------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        629 non-null    int64
#  1   dad_name  629 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 10.0+ KB

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# В таблице `ferma_dad` 629 записей.
# На первый взгляд данные чистенькие - нет пропусков в данных, типы данных верные.

# %% [markdown]
# #### Данные о коровах «ЭкоФермы», которых фермер хочет изучить перед покупкой

# %%
# 3. Выведем информацию о датафрейме 'cow_buy'
head_and_info_display(cow_buy)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~
# ИНФОРМАЦИЯ О ДАТАФРЕЙМЕ
# ~~~~~~~~~~~~~~~~~~~~~~~
# Форма данных: 20 строк, 7 столбцов
#
# Первые 5 строк:
# ---------------
#          breed_cow type_pasture breed_dad_cow  dad_name  \
# 0   Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 1   Вис Бик Айдиал    равнинное       Соверин    Буйный
# 2  РефлешнСоверинг    равнинное       Соверин     Барин
# 3  РефлешнСоверинг    холмистое        Айдиал    Буйный
# 4  РефлешнСоверинг    равнинное        Айдиал    Буйный
#
#    current_fat_content_percent  current_protein_percent          age
# 0                         3.58                    3.076  более_2_лет
# 1                         3.54                    3.081  менее_2_лет
# 2                         3.59                    3.074  более_2_лет
# 3                         3.40                    3.061  более_2_лет
# 4                         3.64                    3.074  более_2_лет
# Общая информация:
# -----------------
# ...

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# В таблице `cow_buy` 20 записей.
# На первый взгляд данные чистенькие - нет пропусков в данных, типы данных верные.

# %% [markdown]
# <div style="background-color: white; border: 1.5px solid violet; border-radius: 10px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# ### <span style="color:violet"> **Вывод**
#
# ---
#
# *1. Мы изменили названия столбцов, приведя их к единому стилю:*
#
# `Удой, кг` на **`milk_kg`**,
#
# `ЭКЕ (Энергетическая кормовая единица)` на **`eke`**,
#
# `Сырой протеин, г` на **`protein_g`**,
#
# `СПО (Сахаро-протеиновое соотношение)` на **`spo`**,
#
# `Порода` на **`breed_cow`**,
#
# `Тип пастбища` на **`type_pasture`**,
#
# `порода папы_быка` на **`breed_dad_cow`**,
#
# `Жирность,%` на **`fat_content_percent`**,
#
# `Белок,%` на **`protein_percent`**,
#
# `Вкус молока` на **`taste_milk`**,
#
# `Возраст` на **`age`**,
#
# `Имя Папы` на **`dad_name`**,
#
# `Имя_папы` на **`dad_name`**,
#
# `Текущая_жирность` на **`current_fat_content_percent`**,
#
# `Текущий_уровень_белок` на **`current_protein_percent`**.
#
# 2. Создали функцию для оперативного и симпатичного вывода общей информации и датафреймах
#
#
# - В таблице `ferma_main` 634 записи.
# - В таблице `ferma_dad` 629 записей.
# - В таблице `cow_buy` 20 записей.
#
# 3. Привели к строчным буквам значения в столбце `type_pasture` таблицы `ferma_main`.
#
# В данных нет пропусков, все колонки нужных типов данных.
#
# ---
#
# **Далее** проведём предоработку данных. Проверим данные в таблицах на дубликаты.
#
# ---

# %% [markdown]
# ##  <span style="color:violet"> Шаг 2. Предобработка данных

# %% [markdown]
# ### Таблица `ferma_main`. Проверка на дубликаты

# %%
# 1. Заменяем неявные дубликаты
ferma_main['type_pasture'] = ferma_main['type_pasture'].str.replace('равнинные', 'равнинное')
ferma_main['breed_dad_cow'] = (ferma_main['breed_dad_cow']
                                        .str.replace('Айдиалл', 'Айдиал')
                                        .str.replace('Соверин', 'Соверинг')
                               )

# %%
# 2. Проверим на явные дубликаты и удалим их, если они имеются
cnt_and_drop_duplicates(ferma_main)
# Out:
# Кол-во дублей ДО: 5
# Кол-во строк ДО: 634
# Кол-во дублей ПОСЛЕ: 0
# Кол-во строк ПОСЛЕ: 629

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# В таблице `ferma_main`
#
# - Выявили 5 явных дубликатов и удалили их. Кол-во строк после удаления явных дубликатов стало 629;
#
# - Нашли и заменили неявные дубликаты:
#
#     - Столбец `type_pasture` : 'равнинные' заменили на 'равнинное'
#     - Столбец `breed_dad_cow` : 'Айдиалл' заменили на 'Айдиал' и 'Соверин' на 'Соверинг'

# %% [markdown]
# ### Таблица `ferma_dad`. Проверка на дубликаты

# %%
# Проверим на явные дубликаты и удалим их, если они имеются
cnt_and_drop_duplicates(ferma_dad)
# Out:
# Кол-во дублей ДО: 0
# Кол-во строк ДО: 629

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# В таблице `ferma_dad` нет дубликатов.

# %% [markdown]
# ### Таблица `cow_buy`. Проверка на дубликаты

# %%
# 1 Заменяем неявные дубликаты
cow_buy['breed_dad_cow'] = cow_buy['breed_dad_cow'].str.replace('Соверин', 'Соверинг')

# %%
# 2. Проверим на явные дубликаты, но удалять не будем
duplicated_cow_buy = cow_buy.duplicated().sum()
print(f'Кол-во дублей: {duplicated_cow_buy}')
# Out:
# Кол-во дублей: 4

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# В таблице `cow_buy`
#
# - Выявили 4 явных дубликата. Удалять не стали, так как они не критичны;
#
# - Нашли и заменили неявные дубликаты:
#
#     - Столбец `breed_dad_cow` : 'Соверин' заменили на 'Соверинг'
#
# Заменили чтобы привести к единым уникальным значениям.

# %% [markdown]
# <div style="background-color: white; border: 1.5px solid violet; border-radius: 10px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# ### <span style="color:violet"> **Вывод**
#
# В данном разделе мы провели первичный анализ и познакомились с данными.
#
# *В таблице `ferma_main`*
#
# - Выявили 5 явных дубликатов и удалили их. Кол-во строк после удаления явных дубликатов стало 629;
#
# - Нашли и заменили неявные дубликаты.
#
# ---
#
# В таблице `ferma_dad` дубликатов не обнаружено.
#
# ---
#
# *В таблице `cow_buy`*
#
# - Кол-во явных дубликатов: 4. Оставили
# - Нашли и заменили неявные дубликаты.
#
# ---
#
# **Далее** приступим к исследовательскому анализу.

# %% [markdown]
# ## <span style="color:violet"> Шаг 3. Исследовательский анализ данных

# %%
# Найдем все категориальные столбцы В таблице 'ferma_main'
categorical_columns = ferma_main.select_dtypes(include=['object']).columns
print('Категориальные столбцы в таблице ferma_main :', list(categorical_columns))

# Найдем все категориальные столбцы В таблице 'ferma_dad'
categorical_columns = ferma_dad.select_dtypes('object').columns
print('Категориальные столбцы в таблице ferma_dad:', list(categorical_columns))
# Out:
# Категориальные столбцы в таблице ferma_main : ['breed_cow', 'type_pasture', 'breed_dad_cow', 'taste_milk', 'age']
# Категориальные столбцы в таблице ferma_dad: ['dad_name']

# %% [markdown]
# ### Статистика и графики распределений для категориальных значений

# %% [markdown]
# #### Порода коровы

# %%
# Построим графики для категориального признака 'breed_cow'
plot_categorical(ferma_main, 'breed_cow')
# Out:
# Статистика для 'breed_cow':
# Всего записей: 634
# Уникальных категорий: 2
# Самая частая категория: 'Вис Бик Айдиал' (373 записей)
# Доля самой частой категории: 58.8%

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# По графику распределения категории `breed_cow` мы видим, что порода "Айдиал" опережает в кол-ве, соответственно и доля от всех коров у нее больше (приближается к 60%).

# %% [markdown]
# #### Тип пастбища

# %%
# Построим графики для категориального признака 'type_pasture'
plot_categorical(ferma_main, 'type_pasture')
# Out:
# Статистика для 'type_pasture':
# Всего записей: 634
# Уникальных категорий: 2
# Самая частая категория: 'холмистое' (356 записей)
# Доля самой частой категории: 56.2%

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# По графику распределения категории `type_pasture` мы видим, что чаще коров пасут на холмистых пастбищах.

# %% [markdown]
# #### Порода отца коровы

# %%
# Построим графики для категориального признака 'breed_dad_cow'
plot_categorical(ferma_main, 'breed_dad_cow')
# Out:
# Статистика для 'breed_dad_cow':
# Всего записей: 634
# Уникальных категорий: 2
# Самая частая категория: 'Айдиал' (318 записей)
# Доля самой частой категории: 50.2%

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# По графику распределения категории `breed_dad_cow` мы видим, что незначительно лидирует порода отца коровы `Айдиал`. Но можно сказать, что они распределены равномерно, слишком уж небольшой отрыв у лидера.

# %% [markdown]
# #### Вкус молока

# %%
# Построим графики для категориального признака 'taste_milk'
plot_categorical(ferma_main, 'taste_milk')
# Out:
# Статистика для 'taste_milk':
# Всего записей: 634
# Уникальных категорий: 2
# Самая частая категория: 'вкусно' (371 записей)
# Доля самой частой категории: 58.5%

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# По графику распределения категории `taste_milk` мы видим, что вкусное молоко встречается чаще. Но не вкусного молока - 41.5% выглядит пугающе многовато, если все не вкусное молоко не выводят на рынок, то это больший убытки. Верное решение обратить внимание на качество продукции.

# %% [markdown]
# #### Возраст коровы

# %%
# Построим графики для категориального признака 'age'
plot_categorical(ferma_main, 'age', palette='Pastel1')
# Out:
# Статистика для 'age':
# Всего записей: 634
# Уникальных категорий: 2
# Самая частая категория: 'более_2_лет' (524 записей)
# Доля самой частой категории: 82.6%

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# По графику распределения категории `age` мы впервые видим большой разрыв в категориальных показателях. Больше 80% - это коровы старше 2 лет, молодых коровок всего 17.4%.

# %% [markdown]
# #### Имя отца коровы

# %%
# Построим графики для категориального признака 'dad_name'
plot_categorical(ferma_dad, 'dad_name')
# Out:
# Статистика для 'dad_name':
# Всего записей: 629
# Уникальных категорий: 4
# Самая частая категория: 'Барин' (240 записей)
# Доля самой частой категории: 38.2%

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# По графику распределения категории `dad_name` мы видим, что Барин весьма плодовит (аж 38.2% коров - его потомство), но и Буйный не сильно отстает(34.2%). Соловчик и Геркулес, возможно, молодые бычки, поэтому не успели достигнуть высот. Возможно, это можно было бы проверить, будь у нас хотя бы точный возраст коровок. Но не уверена, что эта проверка стоит времени и даст какие-то полезные данные.

# %% [markdown]
# ### Статистика и графики распределений для количественных значений

# %%
# Найдем все количественные столбцы В таблице 'cow_buy'
categorical_columns = cow_buy.select_dtypes(include=['float','int']).columns
print('Количественные столбцы в cow_buy:', list(categorical_columns))

# Найдем все количественные столбцы В таблице 'ferma_main'
categorical_columns = ferma_main.select_dtypes(include=['float','int']).columns
print('Количественные столбцы в ferma_main:', list(categorical_columns))
# Out:
# Количественные столбцы в cow_buy: ['current_fat_content_percent', 'current_protein_percent']
# Количественные столбцы в ferma_main: ['id', 'milk_kg', 'eke', 'protein_g', 'spo', 'fat_content_percent', 'protein_percent']

# %% [markdown]
# #### Распределение `Удоя`

# %%
plot_quantitative(ferma_main, 'milk_kg',
                  boxplot_title='Распределение Удоя [Ящик с усами]', 
                  boxplot_ylabel='Кол-во',
                  hist_title='Распределение Удоя [Гистограмма]',
                  hist_xlabel='Масса молока, кг',
                  hist_ylabel='Кол-во')
# Out:
# Статистика для 'milk_kg':
# Кол-во записей: 634
# Среднее: 6187.025
# Стандартное отклонение: 1638.401
# Медиана: 6130.500
# Минимум: 5204.000
# Максимум: 45616.000
# 25-й перцентиль: 5751.750
# 75-й перцентиль: 6501.000

# %%
# Посмотрим поближе на выбросы
ferma_main[ferma_main['milk_kg'] >= 30000]
# Out:
#     id  milk_kg   eke  protein_g   spo       breed_cow type_pasture  \
# 16  17    45616  11.5       1675  0.93  Вис Бик Айдиал    холмистое
#
#    breed_dad_cow  fat_content_percent  protein_percent taste_milk          age
# 16        Айдиал                 3.22            3.076     вкусно  более_2_лет

# %% [markdown]
# <div style="background-color: white; border: 1px solid red; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# По графику распределения категории явные выбросы, которые помешают при обучении модели.
#
# Этот выброс является максимумом. Можно было бы предположить, что допущена ошибка и значение ввели в граммах, но это не так, так как коровке более 2 лет и врядли она всего 45.6 кг дает в год. Но это возможно, если она только попала к фермеру, поэтому данных у нее еще не накапало. Но это не важно, мы уберем это аномальное значение, перезаписав таблицу уже без него.

# %%
# Перезапишем таблицу и вновь выведем графики
ferma_main = ferma_main[ferma_main['milk_kg'] <= 8000]
plot_quantitative(ferma_main, 'milk_kg',
                  boxplot_title='Распределение Удоя [Ящик с усами]', 
                  boxplot_ylabel='Кол-во',
                  hist_title='Распределение Удоя [Гистограмма]',
                  hist_xlabel='Масса молока, кг')
# Out:
# Статистика для 'milk_kg':
# Кол-во записей: 633
# Среднее: 6124.736
# Стандартное отклонение: 474.172
# Медиана: 6130.000
# Минимум: 5204.000
# Максимум: 7222.000
# 25-й перцентиль: 5751.000
# 75-й перцентиль: 6501.000

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# По графику распределения категории `Удой` видим, что масса молока, которую корова даёт в год:
#
# - В среднем 6124.74 кг
# - Медиана 6130.00 кг
# - Стандартное отклонение умеренное: 474.17 кг
#
# На диаграмме не видно явных выбросов, что говорит о стабильности данных. Основная часть значений лежит в диапозоне от 5204 кг до 7222 кг.
#
#     - 75% коров дают более 5751 кг (25-й перцентиль)
#     - 50% коров дают более 6130 кг (медиана)
#     - 25% коров дают более 6501 кг (75-й перцентиль)
#
# Межквартильный размах (диапазон, в котором находится 50% данных):
#
# - От 5751.00 (25-й перцентиль) до 6501.00 (75-й перцентиль).
# - Наибольшее количество коров (пик гистограммы) дает около 6000–6500 кг молока.
#
# **Распределение нормальное** (практически симметричное). Это видно на гистограмме и у ящика с усами тоже (медиана по серидене и усы практически одинаковы). Медиана (6130.00) и среднее (6124.74) близки по значению.

# %% [markdown]
# #### Распределение `ЭКЕ`

# %%
# Выведем графики
plot_quantitative(ferma_main, 'eke',
                  boxplot_title='Распределение питательности корма коровы [Ящик с усами]', 
                  boxplot_ylabel='Кол-во',
                  hist_title='Распределение питательности корма коровы [Гистограмма]',
                  hist_xlabel='ЭКЕ')
# Out:
# Статистика для 'eke':
# Кол-во записей: 633
# Среднее: 14.548
# Стандартное отклонение: 1.297
# Медиана: 14.700
# Минимум: 10.900
# Максимум: 16.800
# 25-й перцентиль: 13.500
# 75-й перцентиль: 15.600

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# По графику распределения категории `ЭКЕ` (Энергетическая кормовая единица) видим, что питательность корма коровы:
#
#     - в среднем 14.55 ЭКЕ
#     - медиана 14.70 ЭКЕ
#     - стандартное отклонение умеренное: 1.30 ЭКЕ
#
# На диаграмме не видно явных выбросов. Пик гистограммы находится в диапазоне 14–15 ЭКЕ.Основная часть значений лежит в диапозоне от 10.9 до 16.8 ЭКЕ.
#
#     - 75% кормов имеют питательность больше 13.50 ЭКЕ (25-й перцентиль)
#     - 50% кормов имеют питательность больше 14.70 ЭКЕ (медиана)
#     - 25% кормов имеют питательность больше 15.60 ЭКЕ (75-й перцентиль)
#
# Межквартильный размах (диапазон, в котором находится 50% данных):
#
# - от 13.50 (25-й перцентиль) до 15.60 (75-й перцентиль).
#
# **Распределение ненормальное** (асимметричное распределение)

# %% [markdown]
# #### Распределение `Сырого протеина`

# %%
# Выведем графики
plot_quantitative(ferma_main, 'protein_g',
                  boxplot_title='Распределение содержания сырого протеина в корме [Ящик с усами]', 
                  boxplot_ylabel='Кол-во',
                  hist_title='Распределение содержания сырого протеина в корме [Гистограмма]',
                  hist_xlabel='масса протеина, г')
# Out:
# Статистика для 'protein_g':
# Кол-во записей: 633
# Среднее: 1923.074
# Стандартное отклонение: 182.270
# Медиана: 1881.000
# Минимум: 1660.000
# Максимум: 2349.000
# 25-й перцентиль: 1773.000
# 75-й перцентиль: 2059.000

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# По графику распределения категории `protein_g` (сырой протеин, г) видим, что содержание сырого протеина в корме:
#
#     - в среднем 1923.07 г
#     - медиана 1881 г
#     - стандартное отклонение умеренное: 182.27 г
#     - минимальное значение: 1660 г
#     - максимальное значение: 2349 г
#     - Разброс: 689 г
#
# На диаграмме не видно явных выбросов. Основная часть значений лежит в диапозоне от 1660 до 2349 г. Пик гистограммы имеет содержание сырого протеина около 1800–2000 г.
#
# Межквартильный размах (диапазон, в котором находится 50% данных):
#
# - от 1773 г (25-й перцентиль) до 2059 г (75-й перцентиль).
#
# **Распределение ненормальное** (асимметричное распределение)

# %% [markdown]
# #### Распределение `СПО`

# %%
# Выведем графики
plot_quantitative(ferma_main, 'spo',
                  boxplot_title='Распределение СПО в корме [Ящик с усами]', 
                  boxplot_ylabel='Кол-во',
                  hist_title='Распределение СПО в корме [Гистограмма]',
                  hist_xlabel='СПО')
# Out:
# Статистика для 'spo':
# Кол-во записей: 633
# Среднее: 0.913
# Стандартное отклонение: 0.032
# Медиана: 0.930
# Минимум: 0.840
# Максимум: 0.960
# 25-й перцентиль: 0.890
# 75-й перцентиль: 0.940

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# По графику распределения категории `СПО` (Сахаро-протеиновое соотношение) видим, что отношение сахара к протеину в корме:
#
#     - в среднем 0.91
#     - медиана 0.93, что указывает на небольшое смещение распределения вправо.
#     - стандартное отклонение низкое: 0.03.
#
# На графике видим, что распределение с двумя пиками.
# Распределение СПО имеет правостороннюю асимметрию, так как медиана выше среднего значения. Основная часть значений лежит в диапозоне от 0.84 до 0.96. Выбросов не наблюдается.
#
# **Распределение ненормальное** (асимметричное распределение)

# %% [markdown]
# <div style="background-color: white; border: 1px solid red; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# Нормы сахаро-протеинового соотношения(Идеальное соотношение: 0.8-1.0):
#
# - 75% кормов с сахаро-протеиновым соотношением больше 0.85 (25-й перцентиль)
# - 50% кормов с сахаро-протеиновым соотношением больше 0.93 (медиана)
# - 25% кормов с сахаро-протеиновым соотношением больше 0.94 (75-й перцентиль)
#
# По результату данного показателя можем сделать вывод об отличном соотношении сахара к протеину. Даже самые низкие значения входят в необходимый диапозон и нет перекоса - максимальное значение тоже входит в "золотую середину".

# %% [markdown]
# #### Распределение  `Жиров в молоке`

# %%
# Выведем графики
plot_quantitative(ferma_main, 'fat_content_percent',
                  boxplot_title='Распределение содержания жиров в молоке [Ящик с усами]', 
                  boxplot_ylabel='Кол-во',
                  hist_title='Распределение содержания жиров в молоке [Гистограмма]',
                  hist_xlabel='Жирность,%')
# Out:
# Статистика для 'fat_content_percent':
# Кол-во записей: 633
# Среднее: 3.605
# Стандартное отклонение: 0.167
# Медиана: 3.650
# Минимум: 2.990
# Максимум: 3.750
# 25-й перцентиль: 3.590
# 75-й перцентиль: 3.720

# %%
# Глянем кол-во выбросов
print(f"Кол-во выбросов: {len(ferma_main[ferma_main['fat_content_percent'] < 3.4 ])}")
print(f"Доля выбросов: {len(ferma_main[ferma_main['fat_content_percent'] < 3.4 ])/633*100:.1f}%")
# Out:
# Кол-во выбросов: 86
# Доля выбросов: 13.6%

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# По графику распределения категории `Жирность` видим, что содержание жиров в молоке:
#
#     - в среднем 3.6%
#     - медиана 3.65%
#     - стандартное отклонение низкое: 0.17%
#
# Основная часть значений лежит в диапозоне от 3.4% до 3.75%. Пик гистограммы имеет содержание жира около 3.6–3.7%.
#
# - 75% коров с содержанием жиров в молоке больше 3.59% (25-й перцентиль)
# - 50% коров с содержанием жиров в молоке больше 3.65% (медиана)
# - 25% коров с содержанием жиров в молоке больше 3.72% (75-й перцентиль)
#
# Основная часть значений с диапозоном от 3.4% до 3.75%. Но есть часть значений (до 25-й перцентиля) от 2.99% с пониженым содержанием жира:
#
# - Кол-во выбросов: 85
# - Доля выбросов: 13.4%
#
# Не думаю, что что-то стоит с ними делать. Оставим как есть.
#
# **Распределение ненормальное** (асимметричное распределение)

# %% [markdown]
# #### Распределение `Белков в молоке`

# %%
# Выведем графики
plot_quantitative(ferma_main, 'protein_percent',
                  boxplot_title='Распределение содержания белков в молоке [Ящик с усами]', 
                  boxplot_ylabel='Кол-во',
                  hist_title='Распределение содержания белков в молоке [Гистограмма]',
                  hist_xlabel='Белок,%')
# Out:
# Статистика для 'protein_percent':
# Кол-во записей: 633
# Среднее: 3.076
# Стандартное отклонение: 0.003
# Медиана: 3.076
# Минимум: 3.069
# Максимум: 3.085
# 25-й перцентиль: 3.074
# 75-й перцентиль: 3.077

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# По графику распределения категории `Белок` видим, что содержание белков в молоке:
#
#     - в среднем 3.08%
#     - медиана 3.08%
#
# Основная часть значений лежит в диапозоне от 3.07% до 3.08%. Выбросы единичные и так как разброс значений в малом диапозоне - оставим их.
#
# Но стандартное отклонение малое (0.003), что настораживает. Возможно дело в некоторой стандартизации при внесении данных.
#
# **Распределение нормальное (симметричное распределение)**

# %% [markdown]
#
# <div style="background-color: white; border: 1px solid red; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# Стандарт содержания белка в молоке:
#
#      - Обычное молоко: 2.8-3.2%
#      - Высокобелковое молоко: > 3.2%
#
# - 75% коров с содержанием белков в молоке больше 3.07% (25-й перцентиль)
# - 50% коров с содержанием белков в молоке больше 3.08% (медиана)
# - 25% коров с содержанием белков в молоке больше 3.08% (75-й перцентиль)

# %% [markdown]
# <div style="background-color: white; border: 1.5px solid violet; border-radius: 10px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# ### <span style="color:violet"> **Вывод**
#
# ---
#
# В данном разделе мы провели статистический анализ всех признаков, прежде разделив их на **категориальные** и **количественные**. Построили графики для каждого признака.
#
#     - Для количественных признаков мы построили: "Ящик с усами" и Гистограмму.
#     - Для категориальных признаков мы построили: Столбчатую и круговую диаграмму.
#
# Так же в данных признаках заметили выбросы:
#
# `Удой` -  убрали аномальное значение 45616 кг молока, перезаписав таблицу уже без него.
#
# `Содержание жиров в молоке` - не трогали (Кол-во выбросов: 86, Доля выбросов: 13.6%). Так как пониженная жирность у данного признака не является аномалией.
#
# `Содержание белков в молоке` - не трогали, так как выбросов мизерное кол-во. И минимальное значение входит в диапазон нормы содержания белка.
#
# ---
#
# ОБЩИЕ ВЫВОДЫ ПО ПРИЗНАКАМ
#
# **Категориальные**
#
# `Порода коровы` Порода "Айдиал" опережает в кол-ве, соответственно и доля от всех коров у нее больше (приближается к 60%).
#
# `Тип пастбища` Чаще коров пасут на холмистых пастбищах.
#
# `Порода отца коровы` Незначительно лидирует порода отца коровы "Айдиал". Но можно сказать, что они распределены равномерно, слишком уж небольшой отрыв у лидера.
#
# `Вкус молока` Вкусное молоко встречается чаще. Но не вкусного молока - 41.5% выглядит пугающе многовато, если все не вкусное молоко не выводят на рынок, то это больший убытки. Верное решение обратить внимание на качество продукции.
#
# `Возраст коровы` Больше 80% - это коровы старше 2 лет, молодых коровок всего 17.4%.
#
# Дополнительно глянули: `Имя отца коровы` Барин весьма плодовит (аж 38.2% коров - его потомство), но и Буйный не сильно отстает(34.2%). У  Соловчика и Геркулеса не так много потомства в сравнении с лидерами - 17.5% и 10.2% соответственно.
#
# **Количественные**
#
# ✅`Удой`  **Распределение нормальное**
#
# Большинство коров дают около 6000–6500 кг молока, что соответствует среднему значению.
# Выбросов нет.
#
# ✅`Белки` **Распределение нормальное**
#
# Большинство значений сосредоточено в диапазоне от 3.07% до 3.08%.
# Выбросов нет.
#
# ❌`ЭКЕ` **Распределение ненормальное**
#
# Большинство значений находятся в диапазоне 14–15 ЭКЕ, что соответствует среднему значению.
# Выбросов нет. НО 25% поголовья получает недостаточное питание (менее 13.5 ЭКЕ), что ниже рекомендуемых 14-16 ЭКЕ.
#
# ❌`Сырой протеин` **Распределение ненормальное**
#
# Большинство значений имеют содержание протеина в диапазоне 1800–2000 г.
# Выбросов нет. НО у 25% поголовья показатели корма находятся на нижней границе нормы (1660-1773 г)
#
# ❌`СПО` **Распределение ненормальное**
#
# Большинство значений сосредоточено в диапазоне от 0.90 до 0.94.
# Выбросов нет.
#
# ❌`Жиры` **Распределение ненормальное**
#
# Большинство значений сосредоточено в диапазоне от 3.4% до 3.75%.
# Кол-во выбросов: 85 (13.4%)
#
#
# ---
#
# **Далее** проведем корреляционный анализ `Удоя` с другими количественными признаками с учетом значения категориальных признаков. Построим диаграммы рассеяния и сделаем выводы о взаимосвязи признаков.

# %% [markdown]
# ## <span style="color:violet"> Шаг 4. Проведём корреляционный анализ признаков в датасете

# %% [markdown]
# - Проверим характер связи целевого и входных признаков с помощью диаграммы рассеяния и тепловой карты (так проще работать с матрицей корреляции).

# %% [markdown]
# ### Изучим взаимосвязь между целевым и входными признаками

# %%
# Выведем тепловую карту phik-корреляций и матрицу 
quick_phik_analysis(ferma_main)

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# TOP-5 признаков по влиянию на `milk_kg`:
# - age: 0.998
# - eke: 0.723
# - fat_content_percent: 0.710
# - spo: 0.662
# - breed_dad_cow: 0.522
#
# TOP-5 признаков по влиянию на `taste_milk`:
# - spo: 0.578
# - eke: 0.280
# - type_pasture: 0.254
# - fat_content_percent: 0.211
# - protein_g: 0.195

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# СИЛЬНАЯ СВЯЗЬ (>0.7)
#
# - ✅ `milk_kg` ~ `age`: 0.998
# - ✅ `milk_kg` ~ `eke`: 0.72
# - ✅ `milk_kg` ~ `fat_content_percent`: 0.71
#
# ---
#
# - ✅ `age` ~ `eke`: 0.77
# - ✅ `age` ~ `spo`: 0.74
#
# ---
#
# УМЕРЕННАЯ СВЯЗЬ (0.3 - 0.7)
#
# - ✅ `milk_kg` ~ `spo`: 0.62
# - ✅ `milk_kg` ~ `breed_dad_cow`: 0.52
# - ✅ `milk_kg` ~ `protein_g`: 0.47
#
# - ✅ `taste_milk` ~ `spo`: 0.58
# - ✅ `taste_milk` ~ `eke`: 0.3
#
# ---
#
# - ❌ protein_percent: 0.06 ~ слабая линейная связь
#
# ---
#
# МУЛЬТИКОЛЛИНЕАРНОСТЬ
#
# - `eke` ↔️ `fat_content_percent` (0.72)
# - `spo` ↔️ `fat_content_percent` (0.65)
# - `eke` ↔️ `spo` (0.6)
#
# ---

# %% [markdown]
# ### Построим диаграммы рассеяния с учетом категориального признака

# %% [markdown]
# Проверим характер связи между между целевыми и входными признаками с помощью диаграммы рассеивания. С учетом категориальных признаков.

# %% [markdown]
# #### Удой от СПО

# %%
# Все диаграммы для СПО
plot_multiple_scatter_trends_with_phik(ferma_main, quant_column='spo')
# Out:
# interval columns not set, guessing: ['spo', 'milk_kg']
# Phik-корреляция: 0.662

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# Коэффициент phik-корреляции между `milk_kg` и `spo` **составляет 0.66**.
#
# <span style="color:violet">1. ТИП ВЗАИМОСВЯЗИ
#
# **Умеренно сильно положительная** - общий восходящий тренд, но не строго линейный.
#
#
# <span style="color:violet">2. ПРИЗНАКИ НЕЛИНЕЙНОСТИ
#
# **Возможны нелинейности** - на диаграмме точки не на одной прямой, но есть общий восходящий тренд, есть изгибы, разные категории по разному реагируют. Наблюдения сгруппированы в два кластера, причём есть такое значение СПО, которое можно считать границей между кластерами (0.90).
#
# ---
#
# <span style="color:violet">АНАЛИЗ ПО КАТЕГОРИЯМ:
#
# По породе коров (`breed_cow`):
#
# - Схожий наклон линейного тренда обеих пород говорит о равномеренном влиянии spo на удой.
# - Порода "Соверенг" демонстрирует более быстрый рост удоя, чем порода "Айдел", хоть и не значительно отличается.
#
# По породе отца (`breed_dad_cow`):
#
# - Также удой увеличивается с ростом spo.
# - Влияние породы отца явно выражено, "Айдиал" показывает лучшие результаты (сравнительнобыстрый рост объма молока).
#
# По возрасту коров (`age`):
#
# - Коровы старше 2 лет имеют более высокие значения удоя по сравнению с молодыми коровами.
# - Удой у молодых коров растет медленнее с увеличением spo, думаю, по той же причине, что и описывала в анализе сырого протеина в корме.
#
# По типу пастбища (`type_pasture`):
#
# - Холмистое пастбище способствует более высоким удоям при одинаковых значениях spo.
# - Равнинное пастбище показывает более низкие значения удоя, но разница не значительна.
#
# По вкусу молока (`taste_milk`):
#
# - Молоко с хорошим вкусом связано с более высоким ростом значения удоя, чем у молока не вкусного.
#
# ---

# %% [markdown]
# #### Удой от ЭКЕ

# %%
# Все диаграммы для ЭКЕ
plot_multiple_scatter_trends_with_phik(ferma_main, quant_column='eke')
# Out:
# interval columns not set, guessing: ['eke', 'milk_kg']
# Phik-корреляция: 0.723

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# Коэффициент Phik-корреляции между `milk_kg` и `eke` **составляет 0.72**
#
# <span style="color:violet">1. ТИП ВЗАИМОСВЯЗИ
#
# **Сильная положительная связь** - точки выстраиваются вдоль прямой линии, постоянный наклон, разброс минимальный
#
#
# <span style="color:violet">2. ПРИЗНАКИ НЕЛИНЕЙНОСТИ
#
# **Возможна нелинейность**  - резкие изменения после определенного значения (плотность точек сгущается к концу, а у коров младше 2 лет наоборот)
#
# ---
#
# <span style="color:violet">АНАЛИЗ ПО КАТЕГОРИЯМ:
#
# По породе коров (`breed_cow`):
#
# - Диаграмма показывает, что `удой` увеличивается с ростом `eke` для обеих пород (`Айдиал` и `Соверинг`).
# - Порода коров `Айдиал` демонстрирует чуть более высокие значения удоя при одинаковых значениях `eke`, но по мере роста `eke` удой сравнивается.
#
# По породе отца (`breed_dad_cow`):
#
# - Аналогично, `удой` возрастает с увеличением `eke`.
#
# - Влияние породы отца на `удой` менее выражено, но `Айдиал` снова показывает лучшие результаты.
#
# По возрасту коров (`age`):
#
# - Коровы с возрастом `более 2 лет` имеют более высокие значения `удоя` по сравнению с молодыми коровами.
#
# - Удой у молодых коров растет медленнее с увеличением `eke`.
#
# По типу пастбища (`type_pasture`):
#
# - Холмистое пастбище способствует более высоким `удоям` при одинаковых значениях `eke`.
#
# - Равнинное пастбище показывает более низкие значения `удоя`. Но их разница не значительна  - линии тренда практически сливаются в одну.
#
# По вкусу молока (`taste_milk`):
#
# - Молоко с хорошим вкусом связано с более высокими значениями `удоя`.
#
# - Не вкусное молоко чаще встречается у коров с низкими значениями `eke`.
#
# ---

# %% [markdown]
# #### Удой от жиров в молоке

# %%
# Все диаграммы для содержания жиров в молоке
plot_multiple_scatter_trends_with_phik(ferma_main, quant_column='fat_content_percent')
# Out:
# interval columns not set, guessing: ['fat_content_percent', 'milk_kg']
# Phik-корреляция: 0.710

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# Коэффициент Phik-корреляции между `milk_kg` и `fat_content_percent` **составляет 0.71**
#
# <span style="color:violet">1. ТИП ВЗАИМОСВЯЗИ
#
# **Сильная положительная связь** - общий восходящий тренд, но не строго линейный.
#
#
# <span style="color:violet">2. ПРИЗНАКИ НЕЛИНЕЙНОСТИ
#
# **Возможны нелинейности** - на диаграмме точки не на одной прямой, но есть общий восходящий тренд, разная скорость роста удоя на разных участках, разные категории по разному реагируют, непостоянная плотность точек - сгущения на определенных участках (зано наибольших значений)
#
# ---
#
# <span style="color:violet">АНАЛИЗ ПО КАТЕГОРИЯМ:
#
# По породе коров (`breed_cow`):
#
# - Линейный тренд для обеих пород имеет схожий наклон, что говорит о равномерном влиянии содержания жира в молоке на удой.
#
# По породе отца (`breed_dad_cow`):
#
# - Также удой увеличивается с ростом spo.
# - Влияние породы отца явно выражено, "Айдиал" показывает лучшие результаты (сравнительно быстрый рост объма молока).
#
# По возрасту коров (`age`):
#
# - Коровы старше 2 лет имеют более высокие значения удоя по сравнению с молодыми коровами.
# - Удой у молодых коров растет практически не меняется с увеличением содержания жирности в молоке.
#
# По типу пастбища (`type_pasture`):
#
# - Холмистое пастбище способствует более высоким удоям при одинаковых значениях содержания жира.
#
# По вкусу молока (`taste_milk`):
#
# - Молоко с хорошим вкусом связано с более высокими значениями удоя, но не намного, линии тренда с увеличением содержания жирности приближаются друг к другу.
#
# ---

# %% [markdown]
# #### Удоя от сырого протеина

# %%
# Все диаграммы для содержания сырого протеина в корме
plot_multiple_scatter_trends_with_phik(ferma_main, quant_column='protein_g')
# Out:
# interval columns not set, guessing: ['protein_g', 'milk_kg']
# Phik-корреляция: 0.467

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# Коэффициент Phik-корреляции между `milk_kg` и `protein_g` **составляет 0.47**
#
# <span style="color:violet">1. ТИП ВЗАИМОСВЯЗИ
#
# **Умеренная положительная связь** - общий восходящий тренд, точки не плотно прилегают к линии тренда, облако точек с заметным рассеянием.
#
#
# <span style="color:violet">2. ПРИЗНАКИ НЕЛИНЕЙНОСТИ
#
# **Отсутствуют** - нет "перегибов" зависимости, плавный монотонный тренд, Равномерное распределение точек вокруг линии тренда
#
# ---
#
# <span style="color:violet">АНАЛИЗ ПО КАТЕГОРИЯМ:
#
# По породе коров (`breed_cow`):
#
# - Наблюдается положительная линейная зависимость между `удоем` и `содержанием протеина`.
# - Породы "Айдиал" и "Соверинг" показывают схожий тренд, но небольшое различие в распределении точек все же имеется - с увеличением показателя сырого протеина в корме породы "Соверинг" удой увеличивается быстрее.
#
# По породе отца (`breed_dad_cow`):
#
# - Наблюдается положительная линейная зависимость между `удоем` и `содержанием протеина`.
# - С увеличением протеина в корме у коров с породами отцов  "Айдиал" и "Соверинг" наблюдается рост удоя. Значительно больше удоя у породы у коров с породой отцов "Айдиал".
#
# По возрасту коров (`age`):
#
# - У коров старше 2 лет наблюдается более высокая зависимость удоя от содержания протеина, чем у коров младше 2 лет.
#
# Это может быть связано с тем, что пока организм молодой коровки растет, питательные вещества идут в большей мере на ее здоровье (укрепление организма, формирование), от этого и удой почти не меняется в объеме.
#
# По типу пастбища (`type_pasture`):
#
# - Два типа пастбища показывают схожий тренд, но различие в распределении точек все же есть - с увеличением показателя сырого протеина в корме коровок, которые пасутся на холмистой местности, удой увеличивается значительно быстрее.
#
# По вкусу молока (`taste_milk`):
#
# - У коров, дающих вкусное молоко - зависимость удоя от содержания протеина чуть больше заметна, чем у коров с невкусным молоком.
#
# ---

# %% [markdown]
# #### Удой от белков

# %%
# Все диаграммы для содержания белков в молоке
plot_multiple_scatter_trends_with_phik(ferma_main, quant_column='protein_percent')
# Out:
# interval columns not set, guessing: ['protein_percent', 'milk_kg']
# Phik-корреляция: 0.057

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# Коэффициент Phik-корреляции между `milk_kg` и `protein_percent` **составляет 0.06**
#
# <span style="color:violet">1. ТИП ВЗАИМОСВЯЗИ
#
# ❌**очень слабую/практически отсутствующую взаимосвязь.**
#
# <span style="color:violet">2. ПРИЗНАКИ НЕЛИНЕЙНОСТИ
#
# ❌**Отсутствуют**
#
#
# Значение `protein_percent` 0.06 указывает, что этот признак, скорее всего, не будет полезен для прогнозирования удоя.
#
# ---

# %% [markdown]
# <div style="background-color: white; border: 1.5px solid violet; border-radius: 10px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# ### <span style="color:violet">  **Вывод**
#
# `УДОЙ`
#
# **1. Тип взаимосвязи между целевым и входными признаками:**
#
# - `spo`: **Умеренно сильно положительная** - общий восходящий тренд, но не строго линейный.
#
# - `eke`: **Сильная положительная связь** - точки выстраиваются вдоль прямой линии, постоянный наклон, разброс минимальный
#
# - `protein_g`: **Умеренная положительная связь** - общий восходящий тренд, точки не плотно прилегают к линии тренда, облако точек с заметным рассеянием.
#
# - `fat_content_percent`: **Сильная положительная связь** - общий восходящий тренд, но не строго линейный.
#
# - `protein_percent`: **Очень слабая связь, практически отсутствует**
#
# **2. Наличие нелинейных связей:**
#
# - `spo`: **Возможны нелинейности** - на диаграмме точки не на одной прямой, но есть общий восходящий тренд, есть изгибы, разные категории по разному реагируют, Наблюдения сгруппированы в два кластера, причём есть такое значение СПО, которое можно считать границей между кластерами (0.90).
#
# - `eke`: **Возможны нелинейности**
#
# - `protein_g`: **Отсутствуют** - нет "перегибов" зависимости, плавный монотонный тренд, Равномерное распределение точек вокруг линии тренда
#
# - `fat_content_percent`: **Возможны нелинейности** - на диаграмме точки не на одной прямой, но есть общий восходящий тренд, разная скорость роста удоя на разных участках, разные категории по разному реагируют, непостоянная плотность точек - сгущения на определенных участках
#
# - `protein_percent`: **Отсутствуют**
#
# **Необходимость ввода дополнительных признаков:**
#
# Для учета нелинейности дополнительные признаки не требуются, поскольку большинство взаимосвязей имеют линейный характер.
#
# **3. Мультиколлинеарность между входными признаками:**
#
# МУЛЬТИКОЛЛИНЕАРНОСТЬ
#
# - `eke` ↔️ `fat_content_percent` (0.72)
# - `spo` ↔️ `fat_content_percent` (0.65)
# - `eke` ↔️ `spo` (0.6)
#
#
# Наблюдается потенциальная мультиколлинеарность между признаками (eke, spo, fat_content_percent), поскольку все они связаны с кормлением (изменение одного параметра кормления автоматически влияет на другие) и демонстрируют значимые корреляции с целевой переменной.
#
# Признак `protein_percent` можно исключить из модели в виду отсутствия значимой связи с удоем.
#
# ---
#
# **Далее** займемся обучением модели линейной регрессии
#
# ---

# %% [markdown]
# ## <span style="color:violet"> Шаг 5. Обучение модели линейной регрессии

# %% [markdown]
# ### Первая модель
#
# Подготовим данные `ferma_main`

# %% [markdown]
# #### Отбор признаков для модели

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 10px 15px; display: inline-block; color: black;">
#
# ПОДХОДЯТ
#
# Характеристики молока: `milk_kg` - Удой, целевой признак
#
# Характеристики корма:
#
# `eke` - Энергетическая кормовая единица. Энергетическая ценность корма напрямую влияет на продуктивность.
# Сильная линейная связь (0.72) - идеален для линейной регрессии
#
#
# `spo` - Сахаро-протеиновое соотношение. Самая сильная связь с целевым признаком. Несмотря на возможные нелинейности, линейная модель даст хорошую базовую точность
#
# `protein_g` - Сырой протеин. Умеренная стабильная связь (0.47). Значимый параметр кормления для здоровья коровы и удоя.
#
# Характеристики коровы:
#
# `age `- Возраст. Сильные различия продуктивности по возрастам.
#
# ДОПОЛНИТЕЛЬНЫЕ:
#
# `breed_cow` - порода коровы. Генетические различия не столь велики, как признак `age`, но все же есть.
#
# `breed_dad_cow` - порода отца коровы.
#
# `type_pasture` - тип пастбища
#
# ИСКЛЮЧИМ:
#
# `fat_content_percent` - Характеристика молока. Нелинейность, возможная мультиколлинеарность с `eke` и `spo`.
#
# `protein_percent` - процент протеина в молоке. Очень слабая корреляция (0.06), не нужен для прогнозирования.
#
# `id` - не нужен для прогнозирования
#
# ---

# %%
#Датафрейм для подготовки данных
ml_ferma = ferma_main.drop(['fat_content_percent', 'protein_percent', 'taste_milk', 'id'], axis=1)
ml_ferma.head(2)
# Out:
#    milk_kg   eke  protein_g   spo       breed_cow type_pasture breed_dad_cow  \
# 0     5863  14.2       1743  0.89  Вис Бик Айдиал    равнинное        Айдиал
# 1     5529  12.8       2138  0.89  Вис Бик Айдиал    равнинное      Соверинг
#
#            age
# 0  более_2_лет
# 1  менее_2_лет

# %%
cat_col_names = ['breed_cow', 'breed_dad_cow', 'age', 'type_pasture'] #список категориальных признаков тренировочной выборки
num_col_names = ['eke', 'protein_g', 'spo']

# %%
model1_ext_data = func_linear_regression_model(ml_ferma, 'milk_kg', cat_col_names, num_col_names, 'Модель 1')
# Out:
# R2_score: 0.75
# Среднее остатков: -22.19
# Медиана остатков: -2.63
# Стандартное отклонение: 214.89
# Минимальный остаток: -622.89
# Максимальный остаток: 661.97

# %%
model1_ext_data[0].head() # проверочка
# Out:
# 330    251.205962
# 248     30.115377
# 391   -186.098057
# 146   -171.933167
# 498    161.261974
# Name: milk_kg, dtype: float64

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
# АНАЛИЗ ОСТАТКОВ:
#
# - Среднее остатков: -22.19
# - Медиана остатков: -2.63
# - Стандартное отклонение: 214.89
# - Минимальный остаток: -622.89
# - Максимальный остаток: 661.97
#
# **R2_score модель 1:** 0.75
#
# - Т.е. в 75% случаев предсказание модели ближе к истине, чем среднее значение целевого признака
#
# **Асимметричное нормальное распределение со смещением влево**
#
# - Cреднее значение смещено влево от нуля и равно −22.19, это говорит о том, что модель часто даёт слишком большие предсказания, её прогнозы больше истинных значений.
#
# - Очень высокое cтандартное отклонение (214.89) в 10 раз превышает среднее значение остатков (-22.19). Что указывает на очень низкую точность модели.
#
# - Очень большой размах ошибок. Разброс от -622 до +661 составляет ~ диапозон 1300 (модель может ошибаться в пределах этого диапазона)
#
# НЕОБХОДИМО:
#
# - Трансформировать данные, чтобы изменить взаимосвязь входных признаков с целевым
#
# ---

# %% [markdown]
# ### Вторая модель
#
# Построим модель линейной регрессии с учётом преобразования признаков, **нелинейно связанных** с целевым признаком

# %%
# Создадим копию датасета для изолированности моделей 
ml_ferma_2 = ferma_main.copy(deep=True)
display(ml_ferma_2.head())
# Out:
#    id  milk_kg   eke  protein_g    spo        breed_cow type_pasture  \
# 0   1     5863  14.2       1743  0.890   Вис Бик Айдиал    равнинное
# 1   2     5529  12.8       2138  0.890   Вис Бик Айдиал    равнинное
# 2   3     5810  14.0       1854  0.885  РефлешнСоверинг    холмистое
# 3   4     5895  12.4       2012  0.885  РефлешнСоверинг    холмистое
# 4   5     5302  12.8       1675  0.885   Вис Бик Айдиал    равнинное
#
#   breed_dad_cow  fat_content_percent  protein_percent taste_milk          age
# 0        Айдиал                 3.58            3.076     вкусно  более_2_лет
# 1      Соверинг                 3.54            3.079     вкусно  менее_2_лет
# 2      Соверинг                 3.59            3.074  не вкусно  более_2_лет
# 3        Айдиал                 3.40            3.075  не вкусно  более_2_лет
# 4      Соверинг                 3.73            3.073     вкусно  менее_2_лет

# %% [markdown]
# #### Исключим нелинейность `СПО` и `Удоя`
#
# Чтобы устранить нелинейность, преобразуем СПО в категориальный бинарный признак, использовав эту границу между кластерами.

# %%
ml_ferma_2['spo_cat'] = ml_ferma_2['spo'].apply(lambda x: 1 if x > 0.90 else 0)
display(ml_ferma_2['spo_cat'].unique()) #проверочка
# Out:
# array([0, 1])

# %% [markdown]
# #### Исключим нелинейность `ЕКЭ` и `Удоя`
#
# Нелинейность между ними исключим, введя новый признак ЭКЕ в квадрате.

# %%
ml_ferma_2['eke_square'] = ml_ferma_2['eke'] ** 2

# %% [markdown]
# #### Создадим вторую модель

# %%
#Датафрейм для подготовки данных
ml_ferma_2 = ml_ferma_2.drop(['fat_content_percent', 'protein_percent', 'id', 'spo', 'eke', 'taste_milk'], axis=1)
ml_ferma_2.head()
# Out:
#    milk_kg  protein_g        breed_cow type_pasture breed_dad_cow  \
# 0     5863       1743   Вис Бик Айдиал    равнинное        Айдиал
# 1     5529       2138   Вис Бик Айдиал    равнинное      Соверинг
# 2     5810       1854  РефлешнСоверинг    холмистое      Соверинг
# 3     5895       2012  РефлешнСоверинг    холмистое        Айдиал
# 4     5302       1675   Вис Бик Айдиал    равнинное      Соверинг
#
#            age  spo_cat  eke_square
# 0  более_2_лет        0      201.64
# 1  менее_2_лет        0      163.84
# 2  более_2_лет        0      196.00
# 3  более_2_лет        0      153.76
# 4  менее_2_лет        0      163.84

# %%
# Разделяем признаки на категориальные и количественные
cat_col_names_2 = ['breed_cow', 'type_pasture', 'breed_dad_cow', 'age','spo_cat']
num_col_names_2 = ['eke_square', 'protein_g']

# %%
model2_ext_data = func_linear_regression_model(ml_ferma_2, 'milk_kg', cat_col_names_2, num_col_names_2, 'Модель 2')
# Out:
# R2_score: 0.79
# Среднее остатков: -19.61
# Медиана остатков: -20.88
# Стандартное отклонение: 197.92
# Минимальный остаток: -672.78
# Максимальный остаток: 592.72

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
# АНАЛИЗ ОСТАТКОВ:
#
# - Среднее остатков: -19.61
# - Медиана остатков: -20.88
# - Стандартное отклонение: 197.92
# - Минимальный остаток: -672.78
# - Максимальный остаток: 592.72
#
# **R2_score модель 2:** 0.79 [Увеличилось на 0.4]
#
# - Т.е. в 79% случаев предсказание модели ближе к истине, чем среднее значение целевого признака
#
# **Асимметричное нормальное распределение со смещением влево**
#
# - Cреднее значение смещено влево от нуля и равно -19.61 [уменьшилось на 2.2], это говорит о том, что модель часто даёт слишком большие предсказания, её прогнозы больше истинных значений.
#
# - Очень высокое cтандартное отклонение (197.92) в 10 раз превышает среднее значение остатков (-19.61). Что указывает на очень низкую точность модели.
#
# - Очень большой размах ошибок. Разброс от -673 до +593 составляет ~ диапозон 1266 (модель может ошибаться в пределах этого диапазона)
#
# НЕОБХОДИМО:
#
# - Найти и добавить в модель дополнительный признак
#
# ---

# %% [markdown]
# ### Третья модель
#
# Добавим в данные новый признак и обучим на них третью модель линейной регрессии

# %% [markdown]
# #### Добавим новый признак и избавимся от нелинейности признаков

# %%
# Добавляем в данные признак 'имя отца коровы' из таблицы 'ferma_dad'
ml_ferma_3 = ferma_main.merge(ferma_dad, on='id')
ml_ferma_3.head(20)
# Out:
#     id  milk_kg   eke  protein_g    spo        breed_cow type_pasture  \
# 0    1     5863  14.2       1743  0.890   Вис Бик Айдиал    равнинное
# 1    2     5529  12.8       2138  0.890   Вис Бик Айдиал    равнинное
# 2    3     5810  14.0       1854  0.885  РефлешнСоверинг    холмистое
# 3    4     5895  12.4       2012  0.885  РефлешнСоверинг    холмистое
# 4    5     5302  12.8       1675  0.885   Вис Бик Айдиал    равнинное
# 5    6     5254  12.7       1806  0.885  РефлешнСоверинг    холмистое
# 6    7     5910  13.2       1792  0.885   Вис Бик Айдиал    равнинное
# 7    8     6179  14.7       1806  0.930   Вис Бик Айдиал    равнинное
# 8    9     6783  14.2       1918  0.940  РефлешнСоверинг    холмистое
# 9   10     5339  13.4       1791  0.895   Вис Бик Айдиал    холмистое
# 10  11     5591  13.7       1678  0.895  РефлешнСоверинг    холмистое
# 11  12     6563  16.5       2328  0.930   Вис Бик Айдиал    холмистое
# ...

# %%
#Чтобы устранить нелинейность, преобразуем СПО в категориальный бинарный признак, использовав эту границу между кластерами.
ml_ferma_3['spo_cat'] = ml_ferma_3['spo'].apply(lambda x: 1 if x > 0.90 else 0)
# Исключим нелинейность ЕКЭ и Удоя, введя новый признак ЭКЕ в квадрате 
ml_ferma_3['eke_square'] = ml_ferma_3['eke'] ** 2
# Сделаем копию модели на будущее для логистической регрессии
lgr_ferma_3 = ml_ferma_3.copy(deep=True)
lgr_ferma_3 = lgr_ferma_3.drop(['fat_content_percent', 'protein_percent', 'id', 
                                'spo', 'eke', 'breed_dad_cow'], axis=1)

# %% [markdown]
# #### Создадим третью модель

# %%
#Датафрейм для подготовки данных
ml_ferma_3 = ml_ferma_3.drop(['fat_content_percent', 'protein_percent', 'id', 'spo', 'taste_milk', 'eke', 'breed_dad_cow'], axis=1)
ml_ferma_3.head()
# Out:
#    milk_kg  protein_g        breed_cow type_pasture          age  dad_name  \
# 0     5863       1743   Вис Бик Айдиал    равнинное  более_2_лет    Буйный
# 1     5529       2138   Вис Бик Айдиал    равнинное  менее_2_лет  Соловчик
# 2     5810       1854  РефлешнСоверинг    холмистое  более_2_лет     Барин
# 3     5895       2012  РефлешнСоверинг    холмистое  более_2_лет    Буйный
# 4     5302       1675   Вис Бик Айдиал    равнинное  менее_2_лет     Барин
#
#    spo_cat  eke_square
# 0        0      201.64
# 1        0      163.84
# 2        0      196.00
# 3        0      153.76
# 4        0      163.84

# %%
# Разделяем признаки на категориальные и количественные
cat_col_names_3 = ['breed_cow', 'type_pasture', 'age', 'dad_name', 'spo_cat']
num_col_names_3 = ['eke_square', 'protein_g']

# %%
model3_ext_data = func_linear_regression_model(ml_ferma_3, 'milk_kg', cat_col_names_3, num_col_names_3, 'Модель 3')
# Out:
# R2_score: 0.80
# Среднее остатков: -11.13
# Медиана остатков: -21.24
# Стандартное отклонение: 192.33
# Минимальный остаток: -711.49
# Максимальный остаток: 560.07

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
# АНАЛИЗ ОСТАТКОВ:
#
# - Среднее остатков: -11.13
# - Медиана остатков: -21.24
# - Стандартное отклонение: 192.33
# - Минимальный остаток: -711.49
# - Максимальный остаток: 560.07
#
# **R2_score модель 3:** 0.80 (+0.01)
#
# - Т.е. в 80% случаев предсказание модели ближе к истине, чем среднее значение целевого признака
#
# **Асимметричное нормальное распределение со смещением влево**
#
# - Cреднее значение смещено влево от нуля и равно -11.13 [уменьшилось на 8.48]
#
# - Стандартное отклонение 192.33 уменьшилось на 4.41.
#
# ---

# %% [markdown]
# ### Сравнение качества трёх моделей линейной регрессии
#
# - Сопоставим R² (вычислили для сравнения регрессионных моделей) и остатки

# %%
metrics_summary = df_metr_storage[['name_model', 'R2', 'Среднее остатков', 'Стандартное отклонение']]
metrics_summary
# Out:
#   name_model        R2  Среднее остатков  Стандартное отклонение
# 0   Модель 1  0.752689        -22.191989              214.891315
# 1   Модель 2  0.790388        -19.609906              197.919610
# 2   Модель 3  0.803343        -11.127246              192.326928

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# Наилучшие показатели у Модели 3
# - Наивысший R²: 0.80
# - Наименьшее Среднее остатков: -11.127246
# - Наименьшее Стандартное отклонение: 192.32

# %% [markdown]
# ### Оценка качества каждой модели по трём метрикам

# %%
df_metr_storage[['name_model', 'R2', 'MSE', 'RMSE', 'MAE']]
# Out:
#   name_model        R2           MSE        RMSE         MAE
# 0   Модель 1  0.752689  46380.332040  215.360934  169.068719
# 1   Модель 2  0.790388  39310.354591  198.268390  153.907277
# 2   Модель 3  0.803343  36880.823521  192.043806  147.687294

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# ЛУЧШАЯ МОДЕЛЬ 3:
#
# - С самым высоким коэффициентом детерминации(0.8), который показывает в скольких процентах случаев предсказание модели точнее, чем среднее значение целевого признака.
# - С самой низкой средней квадратичной ошибкой(36880), которая показывает на какое значение в среднем предсказание отличается от истинного значения (Измеряется в квадратных единицах целевого признака).
# - С самым низким квадратным корнем из средней квадратичной ошибки (192), который показывает на какое значение в среднем предсказание отличается от истинного значения (Измеряется в единицах целевого признака).
# - С самой низкой средней абсолютной ошибкой (147), которая показывает на какое значение предсказание в среднем отличается от истинного значения (Измеряется в единицах целевого признака).
#
# ---
#
# ДАЛЕЕ укажем доверительный интервал прогноза лучшей модели. Для этого рассчитаем квантили ошибки модели на тренировочных данных.
#
# ---

# %%
#Доверительный интервал прогноза. Возможные ошибки предсказанных значений
quantiles=(0.025, 0.975)

lower_quantile = np.quantile(model3_ext_data[0], quantiles[0]).round()
upper_quantile = np.quantile(model3_ext_data[0], quantiles[1]).round()

print(f"Доверительный интервал прогноза: [{lower_quantile}, {upper_quantile}]")
# Out:
# Доверительный интервал прогноза: [-396.0, 345.0]

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
#
# Возможные ошибки предсказанных значений с вероятностью 95% лежат в интервале от -396.0 до 345.0.
#
#
# ---

# %% [markdown]
# ### Прогноз Удоя коров "ЭкоФермы"

# %%
#Создадим копию датасета "cow_buy"
ml_cow_buy = cow_buy.copy(deep=True)

#Увеличим среднее значение каждого из недостоющих признаков на 5%
mean_values = ferma_main[['eke', 'protein_g', 'spo']].mean()
new_values = mean_values * 1.05

# Добавляем недостающие признаки в датасет cow_buy и преобразовываем их как в модели 3
ml_cow_buy['protein_g'] = new_values['protein_g']

ml_cow_buy['eke'] = new_values['eke']
ml_cow_buy['eke_square'] = ml_cow_buy['eke'] ** 2 # Исключаем нелинейность

# Исключаем нелинейность, переведя в бинарный категориальный признак
ml_cow_buy['spo'] = new_values['spo']
ml_cow_buy['spo_cat'] = ml_cow_buy['spo'].apply(lambda x: 1 if x > 0.90 else 0) 

#Датафрейм для подготовки данных
ml_cow_buy = ml_cow_buy.drop(['current_protein_percent', 'breed_dad_cow', 'current_fat_content_percent', 'eke', 'spo'], axis=1)

# Из модели 3 Объединили тренировочную и тестову выборки (чтобы использовать для обучения финальной модели)
# Нужно будет для того, чтобы позже заново кодировать и масштабировать уже полную тренировочную выборку
X_train_final = model3_ext_data[1] 
y_train_final = model3_ext_data[2] 

# Проверка
display(ml_cow_buy.shape)
display(X_train_final.shape)
display(ml_cow_buy.head())
display(X_train_final.head())
# Out:
# (20, 7)
# (633, 7)
#          breed_cow type_pasture  dad_name          age    protein_g  \
# 0   Вис Бик Айдиал    холмистое  Геркулес  более_2_лет  2019.227962
# 1   Вис Бик Айдиал    равнинное    Буйный  менее_2_лет  2019.227962
# 2  РефлешнСоверинг    равнинное     Барин  более_2_лет  2019.227962
# 3  РефлешнСоверинг    холмистое    Буйный  более_2_лет  2019.227962
# 4  РефлешнСоверинг    равнинное    Буйный  более_2_лет  2019.227962
#
#    eke_square  spo_cat
# 0  233.323453        1
# 1  233.323453        1
# 2  233.323453        1
# 3  233.323453        1
# 4  233.323453        1
#    protein_g        breed_cow type_pasture          age  dad_name  spo_cat  \
# 0       1743   Вис Бик Айдиал    равнинное  более_2_лет    Буйный        0
# 1       2138   Вис Бик Айдиал    равнинное  менее_2_лет  Соловчик        0
# 2       1854  РефлешнСоверинг    холмистое  более_2_лет     Барин        0
# 3       2012  РефлешнСоверинг    холмистое  более_2_лет    Буйный        0
# ...

# %%
# Разделяем признаки на категориальные и количественные
cat_col_names_final = ['breed_cow', 'type_pasture', 'dad_name', 'age', 'spo_cat']
num_col_names_final = ['eke_square', 'protein_g']

# %%
# Получим прогноз для коров "ЭкоФермы"

# Кодируем категориальные признаки
encoder = OneHotEncoder(drop='first', sparse=False)
X_train_ohe = encoder.fit_transform(X_train_final[cat_col_names_final])
ml_cow_buy_ohe = encoder.transform(ml_cow_buy[cat_col_names_final])
encoder_col_names = encoder.get_feature_names()

# Масштабируем количественные признаки
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_final[num_col_names_final])
ml_cow_buy_scaled = scaler.transform(ml_cow_buy[num_col_names_final])

# Cоздаём тренировочный и тестовый датафреймы из закодированных и отмасштабированных данных
X_train_ohe = pd.DataFrame(X_train_ohe, columns=encoder_col_names)
ml_cow_buy_ohe = pd.DataFrame(ml_cow_buy_ohe, columns=encoder_col_names)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=num_col_names_final)
ml_cow_buy_scaled = pd.DataFrame(ml_cow_buy_scaled, columns=num_col_names_final)

#объединяем все преобразованные данные в тренировочный и тестовый датафреймы
#и сбрасываем индексы в датафрейме, чтобы избежать ошибок
X_train = pd.concat([X_train_ohe, X_train_scaled], axis=1).reset_index(drop=True)
ml_cow_buy = pd.concat([ml_cow_buy_ohe, ml_cow_buy_scaled], axis=1).reset_index(drop=True)
    
# Создадим модель линейной регрессии и получим прогноз
model_lr = LinearRegression()# инициализируем модель линейной регрессии
model_lr.fit(X_train, y_train_final)# обучим модель на тренировочных данных
predictions = model_lr.predict(ml_cow_buy) #получим предсказания модели на тестовых данных 
cow_buy['pred_milk'] = pd.Series(predictions) # создаем Series из массива и добавляем данные в исходный датфрейм
cow_buy
# Out:
#           breed_cow type_pasture breed_dad_cow  dad_name  \
# 0    Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 1    Вис Бик Айдиал    равнинное      Соверинг    Буйный
# 2   РефлешнСоверинг    равнинное      Соверинг     Барин
# 3   РефлешнСоверинг    холмистое        Айдиал    Буйный
# 4   РефлешнСоверинг    равнинное        Айдиал    Буйный
# 5   РефлешнСоверинг    равнинное      Соверинг  Геркулес
# 6    Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 7    Вис Бик Айдиал    равнинное      Соверинг    Буйный
# 8   РефлешнСоверинг    равнинное      Соверинг     Барин
# 9   РефлешнСоверинг    холмистое        Айдиал    Буйный
# 10   Вис Бик Айдиал    холмистое      Соверинг  Соловчик
# 11  РефлешнСоверинг    равнинное      Соверинг  Геркулес
# 12   Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 13   Вис Бик Айдиал    холмистое      Соверинг     Барин
# 14  РефлешнСоверинг    равнинное      Соверинг     Барин
# ...

# %%
# С учетом доверительного интервала ошибки
suitable_cows_new = cow_buy[(cow_buy['pred_milk'] - upper_quantile) >= 6000]
suitable_cows_new
print(f'Подходящие коровы с учетом доверительного интервала: {len(suitable_cows_new)} из {len(cow_buy)}')
print('Индексы подходящих коров:', suitable_cows_new.index.tolist())
display(suitable_cows_new)
# Out:
# Подходящие коровы с учетом доверительного интервала: 15 из 20
# Индексы подходящих коров: [0, 3, 4, 5, 6, 7, 9, 10, 11, 12, 15, 16, 17, 18, 19]
#           breed_cow type_pasture breed_dad_cow  dad_name  \
# 0    Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 3   РефлешнСоверинг    холмистое        Айдиал    Буйный
# 4   РефлешнСоверинг    равнинное        Айдиал    Буйный
# 5   РефлешнСоверинг    равнинное      Соверинг  Геркулес
# 6    Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 7    Вис Бик Айдиал    равнинное      Соверинг    Буйный
# 9   РефлешнСоверинг    холмистое        Айдиал    Буйный
# 10   Вис Бик Айдиал    холмистое      Соверинг  Соловчик
# 11  РефлешнСоверинг    равнинное      Соверинг  Геркулес
# 12   Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 15  РефлешнСоверинг    холмистое        Айдиал    Буйный
# 16   Вис Бик Айдиал    холмистое      Соверинг  Соловчик
# 17  РефлешнСоверинг    равнинное      Соверинг  Геркулес
# ...

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# Мы определили подходящих коров с учетом доверительного интервала, который показывает, что возможные ошибки предсказанных значений с вероятностью 95% лежат в интервале от -396 до 345.
#
# - Подходящие коровы с учетом доверительного интервала: 15 из 20
# - Индексы подходящих коров: [0, 3, 4, 5, 6, 7, 9, 10, 11, 12, 15, 16, 17, 18, 19]
#
# ---

# %% [markdown]
# <div style="background-color: white; border: 1.5px solid violet; border-radius: 10px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# ### <span style="color:violet">  **Вывод**
#
# ---
#
# ПЕРВАЯ МОДЕЛЬ:
#
# **R2_score модель 1:** 0.75
#
# - Т.е. в 75% случаев предсказание модели ближе к истине, чем среднее значение целевого признака
#
# ---
#
# ВТОРАЯ МОДЕЛЬ:
#
# - Исключили нелинейность:
#
#     - `СПО` и `Удоя` преобразовали СПО в категориальный бинарный признак, использовав границу между кластерами.
#     - `ЕКЭ` и `Удоя` введя новый признак ЭКЕ в квадрате.
#
# **R2_score модель 2:** 0.79 [Увеличилось на 0.4]
#
# Т.е. в 79% случаев предсказание модели ближе к истине, чем среднее значение целевого признака
#
# ---
#
# ТРЕТЬЯ МОДЕЛЬ:
#
# - Добавили новый признак и избавились от нелинейности (как в модели 2)
#
# **R2_score модель 3:** 0.80 (+0.01)
#
# Т.е. в 80% случаев предсказание модели ближе к истине, чем среднее значение целевого признака
#
# ---
#
# **Сравнение качества трех моделей:**
#
# Наилучшие показатели у Модели 3
#
# - Наивысший R²: 0.80
# - Наименьшее Среднее остатков: -11
# - Наименьшее Стандартное отклонение: 192
#
# ---
#
# **Оценка качества каждой модели по трём метрикам:**
#
#     - Модель 1:	R2 = 0.75	MSE = 46380	RMSE = 215	MAE = 169
#     - Модель 2:	R2 = 0.79	MSE = 39310	RMSE = 198	MAE = 153
#
# *Лучшая:*
#
#     - Модель 3:	R2 = 0.80	MSE = 36880	RMSE = 192	MAE = 147
#
# ---
#
# **Прогноз Удоя коров "ЭкоФермы":**
#
# Мы определили подходящих коров с учетом доверительного интервала, который показывает, что возможные ошибки предсказанных значений с вероятностью 95% лежат в интервале от -396.0 до 345.0.
#
# - Подходящие коровы с учетом доверительного интервала: 15 из 20
# - Индексы подходящих коров: [0, 3, 4, 5, 6, 7, 9, 10, 11, 12, 15, 16, 17, 18, 19]
#
# ---

# %% [markdown]
# ## <span style="color:violet"> Шаг 6. Обучение модели логистической регрессии

# %% [markdown]
# ### Подготовим данные и обучим на них модель логистической регрессии

# %%
# Добавляем в данные признак 'имя отца коровы' из таблицы 'ferma_dad'
lgr_ferma = ferma_main.merge(ferma_dad, on='id')
lgr_ferma.head()

# Подготовим данные
lgr_ferma['taste_milk_cat'] = lgr_ferma_3['taste_milk'].apply(lambda x: 1 if x == 'вкусно' else 0)
#Чтобы устранить нелинейность, преобразуем спо в категор. бинарный признак, использовав границу между кластерами
lgr_ferma['spo_cat'] = lgr_ferma['spo'].apply(lambda x: 1 if x > 0.90 else 0)

# Прямое кодироване вручную
#lgr_ferma['dad_name_Буйный'] = ml_ferma_3['dad_name'].apply(lambda x: 1 if x == 'Буйный' else 0)
#lgr_ferma['dad_name_Соловчик'] = ml_ferma_3['dad_name'].apply(lambda x: 1 if x == 'Соловчик' else 0)
#lgr_ferma['dad_name_Барин'] = ml_ferma_3['dad_name'].apply(lambda x: 1 if x == 'Барин' else 0)
#lgr_ferma['dad_name_Геркулес'] = ml_ferma_3['dad_name'].apply(lambda x: 1 if x == 'Геркулес' else 0)

# Исключим нелинейность ЕКЭ и Удоя, введя новый признак ЭКЕ в квадрате 
lgr_ferma['eke_square'] = lgr_ferma['eke'] ** 2
#Датафрейм для подготовки данных
lgr_ferma = lgr_ferma.drop(['id', 'spo', 'eke', 'taste_milk', 'milk_kg'], axis=1)
lgr_ferma.head()
# Out:
#    protein_g        breed_cow type_pasture breed_dad_cow  fat_content_percent  \
# 0       1743   Вис Бик Айдиал    равнинное        Айдиал                 3.58
# 1       2138   Вис Бик Айдиал    равнинное      Соверинг                 3.54
# 2       1854  РефлешнСоверинг    холмистое      Соверинг                 3.59
# 3       2012  РефлешнСоверинг    холмистое        Айдиал                 3.40
# 4       1675   Вис Бик Айдиал    равнинное      Соверинг                 3.73
#
#    protein_percent          age  dad_name  taste_milk_cat  spo_cat  eke_square
# 0            3.076  более_2_лет    Буйный               1        0      201.64
# 1            3.079  менее_2_лет  Соловчик               1        0      163.84
# 2            3.074  более_2_лет     Барин               0        0      196.00
# 3            3.075  более_2_лет    Буйный               0        0      153.76
# 4            3.073  менее_2_лет     Барин               1        0      163.84

# %%
RANDOM_STATE = 42

# разбиваем признаки на входные и целевой
X = lgr_ferma.drop('taste_milk_cat', axis=1)
y = lgr_ferma['taste_milk_cat']

X_train_lgr, X_test_lgr, y_train_lgr, y_test_lgr = train_test_split(X, y, random_state=RANDOM_STATE)

# Разделяем признаки на категориальные и количественные
cat_col_names_lgr = ['breed_cow', 'type_pasture', 'breed_dad_cow', 'age', 'spo_cat', 'dad_name']
num_col_names_lgr = ['protein_g', 'fat_content_percent','protein_percent', 'eke_square']

# Кодируем категориальные признаки
encoder = OneHotEncoder(drop='first', sparse=False)
X_train_lgr_ohe = encoder.fit_transform(X_train_lgr[cat_col_names_lgr])
X_test_lgr_ohe = encoder.transform(X_test_lgr[cat_col_names_lgr])
encoder_col_names_lgr = encoder.get_feature_names()

# Масштабируем количественные признаки
scaler = StandardScaler()
X_train_lgr_scaled = scaler.fit_transform(X_train_lgr[num_col_names_lgr])
X_test_lgr_scaled = scaler.transform(X_test_lgr[num_col_names_lgr])

# Cоздаём тренировочный и тестовый датафреймы из закодированных и отмасштабированных данных
X_train_lgr_ohe = pd.DataFrame(X_train_lgr_ohe, columns=encoder_col_names_lgr)
X_test_lgr_ohe = pd.DataFrame(X_test_lgr_ohe, columns=encoder_col_names_lgr)

X_train_lgr_scaled = pd.DataFrame(X_train_lgr_scaled, columns=num_col_names_lgr)
X_test_lgr_scaled = pd.DataFrame(X_test_lgr_scaled, columns=num_col_names_lgr)

#объединяем все преобразованные данные в тренировочный и тестовый датафреймы
#и сбрасываем индексы в датафрейме, чтобы избежать ошибок
X_train_lgr = pd.concat([X_train_lgr_ohe, X_train_lgr_scaled], axis=1)
X_test_lgr = pd.concat([X_test_lgr_ohe, X_test_lgr_scaled], axis=1)

# %%
# Создадим модель логистической регрессии и получим прогноз
clf = LogisticRegression()# создаём объект для работы с моделью
clf = clf.fit(X_train_lgr, y_train_lgr)# настраиваем модель на данные
y_pred_lgr = clf.predict(X_test_lgr) # получаем прогнозные значения

acc_clf = accuracy_score(y_test_lgr, y_pred_lgr)# проводим оценку точности
recall_clf = recall_score(y_test_lgr, y_pred_lgr)
precision_clf = precision_score(y_test_lgr, y_pred_lgr)

print(f'Accuracy: {acc_clf:.2f}')
print(f'Recall: {recall_clf:.2f}')
print(f'Precision: {precision_clf:.2f}')
# Out:
# Accuracy: 0.64
# Recall: 0.85
# Precision: 0.65

# %% [markdown]
# ### Проанализируем модель логистической регрессии

# %%
# Построение матрицы ошибок
cm = confusion_matrix(y_test_lgr, y_pred_lgr)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r')
plt.ylabel('True label')
plt.xlabel('Predicted');

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# Проаналзируем модель логистической регрессии
#
# - Критичнее всего **ошибка первого рода** False Positive (FP) — это ошибка, когда система ошибочно определяет что молоко вкусное, хотя на самом деле это не так. Precision учитывает такие ошибки и показывает, какая доля объектов, которые модель отнесла к классу 1, действительно принадлежит этому классу. Чем выше значение Precision, тем меньше ошибок первого рода делает модель.  FP ошибок всего 43, сведем их к 0.
# - Чтобы увеличить точнось модели мы поработаем с порогами разделения на классы, чтобы максимизировать метрику Precision.
#
# ---

# %%
# Подбор порога для минимизации False Positive (максимизация Precision)

probabilities_valid = clf.predict_proba(X_test_lgr)# получаем вероятности для X_test_lgr

# Выведем вероятности класса predict_proba() и правильные ответы
y_proba = clf.predict_proba(X_test_lgr)[:, 1] #Берем только вероятности второго столбца (класс 1 - вкусное молоко)
#Создаем удобную таблицу для анализа
proba_data = pd.DataFrame(zip(y_test_lgr, y_proba),#Объединяем данные. т.е. создаем пары (фактический ответ, предсказанная вероятность)
                          columns=['y_test_lgr', 'y_proba']).sort_values(by='y_proba', ascending=False) #сортируем вероятности по убыванию
proba_data.head(10)
# Out:
#      y_test_lgr   y_proba
# 145           1  0.882265
# 66            1  0.848504
# 69            1  0.841366
# 116           1  0.840607
# 55            1  0.826553
# 117           1  0.823187
# 110           1  0.820558
# 1             0  0.816260
# 67            1  0.805261
# 8             1  0.803032

# %%
# Перебираем пороги

proba_data_1 = proba_data.copy(deep=True)#Создаем полную копию исходных данных
# Создаем список порогов
thresholds_1 = [round(i, 2) for i in np.linspace(0.1, 1, num=10, endpoint=False)]
columns = []# создаём переменную, которая будет хранить список новых колонок


# Перебираем каждый порог из списка
for i in thresholds_1: # добавление столбцов с новыми предсказаниями в таблицу
    columns.append('y_pred_' + str(i)) # Формируем имя для новой колонки и добавляем в список
    proba_data_1['y_pred_' + str(i)] = proba_data_1['y_proba'].apply(lambda x: 1 if x > i else 0)# Создаем новую колонку с бинарными предсказаниями

proba_data_1.head(5)
# Out:
#      y_test_lgr   y_proba  y_pred_0.1  y_pred_0.19  y_pred_0.28  y_pred_0.37  \
# 145           1  0.882265           1            1            1            1
# 66            1  0.848504           1            1            1            1
# 69            1  0.841366           1            1            1            1
# 116           1  0.840607           1            1            1            1
# 55            1  0.826553           1            1            1            1
#
#      y_pred_0.46  y_pred_0.55  y_pred_0.64  y_pred_0.73  y_pred_0.82  \
# 145            1            1            1            1            1
# 66             1            1            1            1            1
# 69             1            1            1            1            1
# 116            1            1            1            1            1
# 55             1            1            1            1            1
#
#      y_pred_0.91
# 145            0
# 66             0
# 69             0
# ...

# %%
# Применяем функцию расчета метрик для каждого порога
choice_threshold(thresholds_1, proba_data_1)
# Out:
#    Порог  Precision    Recall Количество FP Число предсказанных объектов  \
# 0   0.10   0.591195  1.000000            65                          159
# 1   0.19   0.591195  1.000000            65                          159
# 2   0.28   0.600000  0.989362            62                          155
# 3   0.37   0.623288  0.968085            55                          146
# 4   0.46   0.621212  0.872340            50                          132
# 5   0.55   0.666667  0.702128            33                           99
# 6   0.64   0.800000  0.510638            12                           60
# 7   0.73   0.838710  0.276596             5                           31
# 8   0.82   1.000000  0.074468             0                            7
# 9   0.91        NaN  0.000000             0                            0
#
#   Всего объектов класса 1
# 0                      94
# 1                      94
# 2                      94
# 3                      94
# 4                      94
# ...

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# Для минимального значения FP и максимального значения Precision оптимальный порог = 0.82.
#
# - Т.к. этот порог со 100% точностью исключит ошибки первого рода, которые нам критически важно избежать.
#
# - Recall при этом = 7.4% (Распознает только наиболее вероятно качественное молоко), маловат, но это закономерно при высоком Precision.
#
# - В данном кейсе это допустимо высокий порог, потому что мы охотимся за качеством молока, а не за кол-ом купленных коров.
#
# - Применим порог к предсказанным вероятностям
#
# ---

# %%
# Делальнее подберем порог 

proba_data_2 = proba_data.copy(deep=True)#Создаем полную копию исходных данных
# Создаем список порогов
thresholds_2 = [round(i, 2) for i in np.linspace(0.64, 0.74, num=10, endpoint=False)] #0.64, 0.74
columns = []# создаём переменную, которая будет хранить список новых колонок

# Перебираем каждый порог из списка
for i in thresholds_2: # добавление столбцов с новыми предсказаниями в таблицу
    columns.append('y_pred_' + str(i)) # Формируем имя для новой колонки и добавляем в список
    proba_data_2['y_pred_' + str(i)] = proba_data_2['y_proba'].apply(lambda x: 1 if x > i else 0)# Создаем новую колонку с бинарными предсказаниями

proba_data_2.head(5)
# Out:
#      y_test_lgr   y_proba  y_pred_0.64  y_pred_0.65  y_pred_0.66  y_pred_0.67  \
# 145           1  0.882265            1            1            1            1
# 66            1  0.848504            1            1            1            1
# 69            1  0.841366            1            1            1            1
# 116           1  0.840607            1            1            1            1
# 55            1  0.826553            1            1            1            1
#
#      y_pred_0.68  y_pred_0.69  y_pred_0.7  y_pred_0.71  y_pred_0.72  \
# 145            1            1           1            1            1
# 66             1            1           1            1            1
# 69             1            1           1            1            1
# 116            1            1           1            1            1
# 55             1            1           1            1            1
#
#      y_pred_0.73
# 145            1
# 66             1
# 69             1
# ...

# %%
# Примененяем функции расчета метрик для каждого порога
choice_threshold(thresholds_2, proba_data_2)
# Out:
#    Порог  Precision    Recall Количество FP Число предсказанных объектов  \
# 0   0.64   0.800000  0.510638            12                           60
# 1   0.65   0.833333  0.478723             9                           54
# 2   0.66   0.857143  0.446809             7                           49
# 3   0.67   0.844444  0.404255             7                           45
# 4   0.68   0.853659  0.372340             6                           41
# 5   0.69   0.837838  0.329787             6                           37
# 6   0.70   0.837838  0.329787             6                           37
# 7   0.71   0.828571  0.308511             6                           35
# 8   0.72   0.823529  0.297872             6                           34
# 9   0.73   0.838710  0.276596             5                           31
#
#   Всего объектов класса 1
# 0                      94
# 1                      94
# 2                      94
# 3                      94
# 4                      94
# ...

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# Подстрахуемся и выберем порог меньше (следуя принципу: минимизируем значения FP и максимизируем значения Precision)
#
#
# - Порог 0.68 - Лучший для минимизации FP
#
# - Precision: 85.4% (т.е. у одной из 6 коров, у которых предсказано вкусное молоко, будет не вкусное молоко)
#
# - FP: 6 (минимальное количество ложных предсказаний)
#
# - Recall: 37.2% (ниже, но все же находит 37% реальных объектов)
#
# ---

# %%
# Выделяем оптимальный порог
optimal_threshold = 0.82

# Применение порога к предсказанным вероятностям
y_pred_threshold = (y_proba > optimal_threshold).astype(int)

new_acc_clf = accuracy_score(y_test_lgr, y_pred_threshold)
new_recall_clf = recall_score(y_test_lgr, y_pred_threshold)
new_precision_clf = precision_score(y_test_lgr, y_pred_threshold)

print('Сравнение метрик:')
print(f'Accuracy:  {acc_clf:.2f} → {new_acc_clf:.2f} ({new_acc_clf - acc_clf:.2f})')
print(f'Recall:    {recall_clf:.2f} → {new_recall_clf:.2f} ({new_recall_clf - recall_clf:.2f})')
print(f'Precision: {precision_clf:.2f} → {new_precision_clf:.2f} ({new_precision_clf - precision_clf:+.2f})')
# Out:
# Сравнение метрик:
# Accuracy:  0.64 → 0.45 (-0.19)
# Recall:    0.85 → 0.07 (-0.78)
# Precision: 0.65 → 1.00 (+0.35)

# %%
# Построение матрицы ошибок для порога 0.82
cm = confusion_matrix(y_test_lgr, y_pred_threshold)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r')
plt.ylabel('True label')
plt.xlabel('Predicted');

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# **СРАВНЕНИЕ МЕТРИК  С ПОРОГОМ 0.5 и порогом 0.82**
#
# ACCURACY:  **0.64 → 0.45** (-0.19)
# - Общая точность снизилась на 19%, это закономерно ведь мы подныли порог
#
# RECALL:    **0.85 → 0.075** (-0.78)
#
# - Раньше находил 85% вкусного молока, но каждый третий раз ошибался, теперь 7% находит вкусное молоко и не ошибается.
#
# PRECISION: **0.65 → 1** (+0.35)
#
# - Надежность положительных прогнозов достигла 100% - рост на 35% с предыдущего уровня
#
# ---

# %%
# Выделяем запасной порог
reserve_threshold = 0.68

# Применение порога к предсказанным вероятностям
y_pred_threshold_reserve = (y_proba > reserve_threshold).astype(int)

new_acc_clf_reserve = accuracy_score(y_test_lgr, y_pred_threshold_reserve)
new_recall_clf_reserve = recall_score(y_test_lgr, y_pred_threshold_reserve)
new_precision_clf_reserve = precision_score(y_test_lgr, y_pred_threshold_reserve)

print('Сравнение метрик:')
print(f'Accuracy:  {acc_clf:.2f} → {new_acc_clf_reserve:.2f} ({new_acc_clf_reserve - acc_clf:.2f})')
print(f'Recall:    {recall_clf:.2f} → {new_recall_clf_reserve:.2f} ({new_recall_clf_reserve - recall_clf:.2f})')
print(f'Precision: {precision_clf:.2f} → {new_precision_clf_reserve:.2f} ({new_precision_clf_reserve - precision_clf:+.2f})')
# Out:
# Сравнение метрик:
# Accuracy:  0.64 → 0.59 (-0.05)
# Recall:    0.85 → 0.37 (-0.48)
# Precision: 0.65 → 0.85 (+0.20)

# %%
# Построение матрицы ошибок для порога 0.68
cm = confusion_matrix(y_test_lgr, y_pred_threshold_reserve)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues_r')
plt.ylabel('True label')
plt.xlabel('Predicted')
# Out:
# Text(0.5, 15.0, 'Predicted')

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# **СРАВНЕНИЕ МЕТРИК  С ПОРОГОМ 0.5 и порогом 0.68**
#
# ACCURACY:  **0.64 → 0.59** (-0.05)
# - Общая точность снизилась на 5%
#
# RECALL:    **0.85 → 0.37** (-0.48)
#
# - Раньше находил 85% вкусного молока, но каждый третий раз ошибался, теперь 37% находит вкусное молоко и ошибается каждый шестой раз.
#
# PRECISION: **0.65 → 0.85** (+0.20)
#
# - Надежность положительных прогнозов достигла 85% - рост на 20%
#
# ---
#
# С помощью обученной модели спрогнозируем вкус молока коров, которых фермер хочет купить

# %% [markdown]
# ### Прогноз Вкуса молока коров "ЭкоФермы"

# %%
# Выполним подготовку данных для финального прогнозирования

#Создадим копию датасета "cow_buy"
ml_cow_buy_2 = cow_buy.copy(deep=True)
lgr_ferma_final = lgr_ferma.copy(deep=True)

#Увеличим среднее значение каждого из недостоющих признаков на 5%
mean_values_2 = ferma_main[['eke', 'protein_g', 'spo']].mean()
new_values_2 = mean_values_2 * 1.05

# Добавляем недостающие признаки в датасет cow_buy и преобразовываем их как в модели 3
ml_cow_buy_2['protein_g'] = new_values_2['protein_g']

ml_cow_buy_2['eke'] = new_values_2['eke']
ml_cow_buy_2['eke_square'] = ml_cow_buy_2['eke'] ** 2 # Исключаем нелинейность

# Исключаем нелинейность, переведя в бинарный категориальный признак
ml_cow_buy_2['spo'] = new_values_2['spo']
ml_cow_buy_2['spo_cat'] = ml_cow_buy_2['spo'].apply(lambda x: 1 if x > 0.90 else 0) 

#Датафрейм для подготовки данных
ml_cow_buy_2 = ml_cow_buy_2.drop(['eke', 'spo', 'pred_milk'], axis=1)
ml_cow_buy_2.rename(columns={'current_fat_content_percent': 'fat_content_percent', 
                             'current_protein_percent': 'protein_percent'}, inplace=True)

# Полная тренировочная выборка для финального прогнозирования [разделенная]
X_train_final_2 = lgr_ferma.drop('taste_milk_cat', axis=1)# входные признаки
y_train_final_2 = lgr_ferma['taste_milk_cat']#целевые признаки

# Проверка
display(ml_cow_buy_2.shape)
display(X_train_final_2.shape)
display(ml_cow_buy_2.head())
display(X_train_final_2.head())
# Out:
# (20, 10)
# (633, 10)
#          breed_cow type_pasture breed_dad_cow  dad_name  fat_content_percent  \
# 0   Вис Бик Айдиал    холмистое        Айдиал  Геркулес                 3.58
# 1   Вис Бик Айдиал    равнинное      Соверинг    Буйный                 3.54
# 2  РефлешнСоверинг    равнинное      Соверинг     Барин                 3.59
# 3  РефлешнСоверинг    холмистое        Айдиал    Буйный                 3.40
# 4  РефлешнСоверинг    равнинное        Айдиал    Буйный                 3.64
#
#    protein_percent          age    protein_g  eke_square  spo_cat
# 0            3.076  более_2_лет  2019.227962  233.323453        1
# 1            3.081  менее_2_лет  2019.227962  233.323453        1
# 2            3.074  более_2_лет  2019.227962  233.323453        1
# 3            3.061  более_2_лет  2019.227962  233.323453        1
# 4            3.074  более_2_лет  2019.227962  233.323453        1
#    protein_g        breed_cow type_pasture breed_dad_cow  fat_content_percent  \
# ...

# %%
# Разделяем признаки на категориальные и количественные
cat_col_names_final_2 = ['breed_cow', 'type_pasture', 'breed_dad_cow', 'dad_name', 'age', 'spo_cat']
num_col_names_final_2 = ['eke_square', 'protein_g', 'protein_percent', 'fat_content_percent']

# %%
# Кодируем категориальные признаки
encoder = OneHotEncoder(drop='first', sparse=False)
X_train_final_2_ohe = encoder.fit_transform(X_train_final_2[cat_col_names_final_2])
ml_cow_buy_2_ohe = encoder.transform(ml_cow_buy_2[cat_col_names_final_2])
encoder_col_names_lgr_2 = encoder.get_feature_names()

# Масштабируем количественные признаки
scaler = StandardScaler()
X_train_final_2_scaled = scaler.fit_transform(X_train_final_2[num_col_names_final_2])
ml_cow_buy_2_scaled = scaler.transform(ml_cow_buy_2[num_col_names_final_2])

# Cоздаём тренировочный и тестовый датафреймы из закодированных и отмасштабированных данных
X_train_final_2_ohe = pd.DataFrame(X_train_final_2_ohe, columns=encoder_col_names_lgr_2)
ml_cow_buy_2_ohe = pd.DataFrame(ml_cow_buy_2_ohe, columns=encoder_col_names_lgr_2)

X_train_final_2_scaled = pd.DataFrame(X_train_final_2_scaled, columns=num_col_names_final_2)
ml_cow_buy_2_scaled = pd.DataFrame(ml_cow_buy_2_scaled, columns=num_col_names_final_2)

#объединяем все преобразованные данные в тренировочный и тестовый датафреймы
#и сбрасываем индексы в датафрейме, чтобы избежать ошибок
X_train_final_2 = pd.concat([X_train_final_2_ohe, X_train_final_2_scaled], axis=1)
ml_cow_buy_2 = pd.concat([ml_cow_buy_2_ohe, ml_cow_buy_2_scaled], axis=1)

# %%
# Получим прогноз с оптимальным порогом
clf.fit(X_train_final_2, y_train_final_2) # настраиваем модель на данные
y_proba = clf.predict_proba(ml_cow_buy_2)[:, 1] # получаем прогнозные значения
predictions_final_2 = (y_proba > optimal_threshold).astype(int)#применение порога

cow_buy['pred_taste'] = predictions_final_2
cow_buy['pred_taste'] = cow_buy['pred_taste'].apply(lambda x: 'вкусно' if x == 1 else 'не вкусно')
to_buy = cow_buy.query('pred_taste == "вкусно"')
cow_buy
# Out:
#           breed_cow type_pasture breed_dad_cow  dad_name  \
# 0    Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 1    Вис Бик Айдиал    равнинное      Соверинг    Буйный
# 2   РефлешнСоверинг    равнинное      Соверинг     Барин
# 3   РефлешнСоверинг    холмистое        Айдиал    Буйный
# 4   РефлешнСоверинг    равнинное        Айдиал    Буйный
# 5   РефлешнСоверинг    равнинное      Соверинг  Геркулес
# 6    Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 7    Вис Бик Айдиал    равнинное      Соверинг    Буйный
# 8   РефлешнСоверинг    равнинное      Соверинг     Барин
# 9   РефлешнСоверинг    холмистое        Айдиал    Буйный
# 10   Вис Бик Айдиал    холмистое      Соверинг  Соловчик
# 11  РефлешнСоверинг    равнинное      Соверинг  Геркулес
# 12   Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 13   Вис Бик Айдиал    холмистое      Соверинг     Барин
# 14  РефлешнСоверинг    равнинное      Соверинг     Барин
# ...

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# С порогом 0.82 у всех коров не вкусное молоко (видимо очень высокий порог для выборки в 20 коров). Попробуем получить прогноз с запасным порогом
#
# ---

# %%
# Получим прогноз с запасным порогом 0.68
clf.fit(X_train_final_2, y_train_final_2) # настраиваем модель на данные
y_proba = clf.predict_proba(ml_cow_buy_2)[:, 1] # получаем прогнозные значения
predictions_final_2_reserve = (y_proba > reserve_threshold).astype(int)#применение порога reserve_threshold

# Находим подходящих коров
cow_buy['pred_taste'] = predictions_final_2_reserve
cow_buy['pred_taste'] = cow_buy['pred_taste'].apply(lambda x: 'вкусно' if x == 1 else 'не вкусно')
to_buy = cow_buy.query('pred_taste == "вкусно"')

print(f'Подходящие коровы с учетом вкуса: {len(to_buy)} из {len(cow_buy)}')
print('Индексы подходящих коров:', to_buy.index.tolist())
display(to_buy)
# Out:
# Подходящие коровы с учетом вкуса: 5 из 20
# Индексы подходящих коров: [0, 6, 9, 13, 16]
#           breed_cow type_pasture breed_dad_cow  dad_name  \
# 0    Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 6    Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 9   РефлешнСоверинг    холмистое        Айдиал    Буйный
# 13   Вис Бик Айдиал    холмистое      Соверинг     Барин
# 16   Вис Бик Айдиал    холмистое      Соверинг  Соловчик
#
#     current_fat_content_percent  current_protein_percent          age  \
# 0                          3.58                    3.076  более_2_лет
# 6                          3.58                    3.076  более_2_лет
# 9                          3.40                    3.079  менее_2_лет
# 13                         3.42                    3.075  менее_2_лет
# 16                         3.73                    3.079  более_2_лет
#
#       pred_milk pred_taste
# 0   6582.458852     вкусно
# 6   6582.458852     вкусно
# ...

# %% [markdown]
# <div style="background-color: white; border: 1px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# Подходящие коровы с учетом вкуса: 5 из 20
# Индексы подходящих коров: [0, 6, 9, 13, 16]
#
# ---

# %% [markdown]
# <div style="background-color: white; border: 1.5px solid violet; border-radius: 10px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# ### <span style="color:violet">  **Вывод**
#
# МОДЕЛЬ 1
#
# Accuracy: 0.64
# Recall: 0.85
# Precision: 0.65
#
#
# Проаналзируем модель логистической регрессии
#
# - Критичнее всего **ошибка первого рода** False Positive (FP) — это ошибка, когда система ошибочно определяет что молоко вкусное, хотя на самом деле это не так. Precision учитывает такие ошибки и показывает, какая доля объектов, которые модель отнесла к классу 1, действительно принадлежит этому классу. Чем выше значение Precision, тем меньше ошибок первого рода делает модель.  FP ошибок всего 43, сведем их к 0.
# - Чтобы увеличить точнось модели мы поработаем с порогами разделения на классы, чтобы максимизировать метрику Precision.
#
# ПОДБОР ПОРОГА (для минимизации False Positive и максимизация Precision)
#
# ---
#
# **Порог = 0.82**
#
# Precision = 1 (этот порог со 100% точностью исключит ошибки первого рода)
# FP: 0 (нет ложных предсказаний)
# Recall = 7.4% (распознает только наиболее вероятно качественное молоко)
#
#
# СРАВНЕНИЕ МЕТРИК  С ПОРОГОМ 0.5 и порогом 0.82
#
# ACCURACY:  **0.64 → 0.45** (-0.19)
# - Общая точность снизилась на 19%, это закономерно ведь мы подныли порог
#
# RECALL:    **0.85 → 0.075** (-0.78)
#
# - Раньше находил 85% вкусного молока, но каждый третий раз ошибался, теперь 7% находит вкусное молоко и не ошибается.
#
# PRECISION: **0.65 → 1.0000** (+0.35)
#
# - Надежность положительных прогнозов достигла 100% - рост на 35% с предыдущего уровня
#
# ---
#
# **Порог = 0.68**
#
# Precision: 85.4% (т.е. у одной из 6 коров, у которых предсказано вкусное молоко, будет не вкусное молоко)
#
# FP: 6 (минимальное количество ложных предсказаний)
#
# Recall: 37.2% (ниже, но все же находит 37% реальных объектов)
#
#
# СРАВНЕНИЕ МЕТРИК  С ПОРОГОМ 0.5 и порогом 0.68
#
# ACCURACY:  **0.64 → 0.59** (-0.05)
# - Общая точность снизилась на 5%
#
# RECALL:    **0.85 → 0.37** (-0.48)
#
# - Раньше находил 85% вкусного молока, но каждый третий раз ошибался, теперь 37% находит вкусное молоко и ошибается каждый шестой раз.
#
# PRECISION: **0.65 → 0.85** (+0.20)
#
# - Надежность положительных прогнозов достигла 85% - рост на 20%
#
# ---
#
# ПРОГНОЗ ВКУСА МОЛОКА КОРОВ "ЭкоФермы"
#
# - С порогом 0.82 у всех коров не вкусное молоко (видимо очень высокий порог для выборки в 20 коров)
# - Подходящие коровы с учетом вкуса: 5 из 20
# - Индексы подходящих коров: [0, 6, 9, 13, 16]
#
# ---

# %% [markdown]
# ## <span style="color:violet"> Итоговые выводы

# %% [markdown]
# <div style="background-color: white; border: 7px solid black; border-radius: 0px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
#
# 1. Чтобы не понести убытки, фермеру не стоит покупать коров.
#
# При пороге 0.82 точность отбора составила 100% (т.е. все коровы гарантированно дают вкусное молоко). Но не найдено ни одной коровы, соответствующей такому высокому стандарту.
#
# 2. Если фермер готов рисковать (но не слишком):
#
# При пороге 0.68 точность отбора составила 85.4% (примерно 1 из 6 коров дает не вкусное молоко). Выявлено 5 коров с вкусным молоком.
#
# РИСКИ:
#
# - 5%, что корова имеет недостаточный удой и при этом 14.6% - вероятность отобрать корову с не вкусным молоком.
#
# ---
#
# Если фермер выбирает не много рискнуть, то ниже рекомендованный список коров с прогнозированным удоем более 6000 килограммов в год (с учетом доверительного интервала) и вкусное молоко. Четыре коровы с индексами [0, 6, 9, 16]:
#
# ---

# %%
#Выберем коров, подходящих по двум спрогнозированным параметрам
cow_buy.loc[((cow_buy['pred_milk'] - upper_quantile) >= 6000) & (cow_buy['pred_taste'] == 'вкусно')]
# Out:
#           breed_cow type_pasture breed_dad_cow  dad_name  \
# 0    Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 6    Вис Бик Айдиал    холмистое        Айдиал  Геркулес
# 9   РефлешнСоверинг    холмистое        Айдиал    Буйный
# 16   Вис Бик Айдиал    холмистое      Соверинг  Соловчик
#
#     current_fat_content_percent  current_protein_percent          age  \
# 0                          3.58                    3.076  более_2_лет
# 6                          3.58                    3.076  более_2_лет
# 9                          3.40                    3.079  менее_2_лет
# 16                         3.73                    3.079  более_2_лет
#
#       pred_milk pred_taste
# 0   6582.458852     вкусно
# 6   6582.458852     вкусно
# 9   6371.892996     вкусно
# 16  6348.256890     вкусно

# %% [markdown]
# <div style="background-color: white; border: 2px solid violet; border-radius: 20px; padding: 15px 25px; display: inline-block; color: black;">
#
# ---
#
# <span style="color:violet"> **Вывод**
#
# ---
#
# <span style="color:violet"> **шаг 1** ИЗУЧЕНИЕ ДАННЫХ
#
# ---
#
# - Мы изменили названия столбцов, приведя их к единому стилю;
#
# - Создали функцию для оперативного и симпатичного вывода общей информации и датафреймах:
#
#     - В таблице `ferma_main` 634 записей.
#     - В таблице `ferma_dad` 629 записей.
#     - В таблице `cow_buy` 20 записей.
#
# - Привели к строчным буквам значения в столбце `type_pasture` таблицы `ferma_main`.
#
# В данных пропусков не обнаружено, все колонки нужных типов данных.
#
# ---
#
# <span style="color:violet"> **шаг 2** ПРЕДОРАБОТКА ДАННЫХ
#
# ---
#
# *В таблице `ferma_main`*
#
# - Выявили 5 явных дубликатов и удалили их. Кол-во строк после удаления явных дубликатов стало 629;
#
# - Нашли и заменили неявные дубликаты.
#
# *В таблице `ferma_dad` дубликатов не обнаружено.*
#
# *В таблице `cow_buy`*
#
# - Кол-во дублей: 4
# - Нашли и заменили неявные дубликаты.
#
# ---
#
# <span style="color:violet"> **шаг 3** ИССЛЕДОВАТЕЛЬССКИЙ АНАЛИЗ ДАННЫХ
# ___
#
# 1. В данном разделе мы провели статистический анализ всех признаков, прежде разделив их на **категориальные и количественные**.
#
# 2. Построили графики для каждого признака.
#
# - Для количественных признаков мы построили: "Ящик с усами" и Гистограмму.
# - Для категориальных признаков мы построили: Столбчатую и круговую диаграмму.
#
# 3. Так же в данных признаках заметили выбросы:
#
# - `Удой` - убрали аномальное значение 45616 кг молока, перезаписав таблицу уже без него.
# - `Содержание жиров в молоке` - не трогали (Кол-во выбросов: 86, Доля выбросов: 13.6%). Так как пониженная жирность у данного признака не является аномалией.
# - `Содержание белков в молоке` - не трогали, так как выбросов мизерное кол-во. И минимальное значение входит в диапазон нормы содержания белка.
#
# Удой превышает целевые показатели (6124 кг при плане 6000 кг), а сахаро-протеиновое соотношение идеально сбалансировано.
#
# Однако обнаружены критические проблемы:
#
#     - 25% коров получают недостаточное энергетическое питание (меньше 13.5 ЭКЕ),
#     - 41.5% молока имеет неудовлетворительный вкус,
#     - подозрительно одинаковые показатели белка требуют проверки измерительного оборудования.
#
# *Более подробно описаны признаки в Выводе "Шаг 3".
#
# ---
#
# <span style="color:violet"> **шаг 4** КОРРЕЛЯЦИОННЫЙ АНАЛИЗ
#
# ---
# В данном разделе мы провели корреляционный анализ.
#
#     - Построили визуализацию матрицы phik-корреляции
#     - Построили диаграммы рассеяния с линиями тренда с учетом категориальных значений
#     - Выявили взаимосвязи между целевым и входными признаками, наличие нелинейных связей
#
# **1. Тип взаимосвязи между целевым и входными признаками:**
#
# - `spo`: **Умеренно сильно положительная** - общий восходящий тренд, но не строго линейный.
#
# - `eke`: **Сильная положительная связь** - точки выстраиваются вдоль прямой линии, постоянный наклон, разброс минимальный
#
# - `protein_g`: **Умеренная положительная связь** - общий восходящий тренд, точки не плотно прилегают к линии тренда, облако точек с заметным рассеянием.
#
# - `fat_content_percent`: **Сильная положительная связь** - общий восходящий тренд, но не строго линейный.
#
# - `protein_percent`: **Очень слабая связь, практически отсутствует**
#
# **2. Наличие нелинейных связей:**
#
# - `spo`: **Возможны нелинейности** - на диаграмме точки не на одной прямой, но есть общий восходящий тренд, есть изгибы, разные категории по разному реагируют, Наблюдения сгруппированы в два кластера, причём есть такое значение СПО, которое можно считать границей между кластерами (0.90).
#
# - `eke`: **Возможны нелинейности**
#
# - `protein_g`: **Отсутствуют** - нет "перегибов" зависимости, плавный монотонный тренд, Равномерное распределение точек вокруг линии тренда
#
# - `fat_content_percent`: **Возможны нелинейности** - на диаграмме точки не на одной прямой, но есть общий восходящий тренд, разная скорость роста удоя на разных участках, разные категории по разному реагируют, непостоянная плотность точек - сгущения на определенных участках
#
# - `protein_percent`: **Отсутствуют**
#
# **Необходимость ввода дополнительных признаков:**
#
# Для учета нелинейности дополнительные признаки не требуются, поскольку большинство взаимосвязей имеют линейный характер.
#
# **3. Мультиколлинеарность между входными признаками:**
#
# МУЛЬТИКОЛЛИНЕАРНОСТЬ
#
# - `eke` ↔️ `fat_content_percent` (0.72)
# - `spo` ↔️ `fat_content_percent` (0.65)
# - `eke` ↔️ `spo` (0.6)
#
# Наблюдается потенциальная мультиколлинеарность между признаками (eke, spo, fat_content_percent), поскольку все они связаны с кормлением (изменение одного параметра кормления автоматически влияет на другие) и демонстрируют значимые корреляции с целевой переменной.
#
# ---
#
# <span style="color:violet"> **шаг 5** ОБУЧЕНИЕ МОДЕЛИ ЛИНЕЙНОЙ РЕГРЕССИИ. ПРОГНОЗИРОВАНИЕ `Удоя`
#
# ---
#
# МОДЕЛЬ 1
#
# 1. Использовались такие входные признаки, как `breed_cow`, `breed_dad_cow`, `age`, `type_pasture`, `eke`, `protein_g`, `spo`.
#
# 2. Результат регрессии был следующим:
#
# - Коэффициент детерминации 0.75
#
#     - Т.е. в 75% случаев предсказание модели ближе к истине, чем среднее значение целевого признака
#
# 3. Было необходимо:
#
# Трансформировать данные, чтобы изменить взаимосвязь входных признаков с целевым
#
# МОДЕЛЬ 2
#
# 1. Использовались такие входные признаки, как `breed_cow`, `breed_dad_cow`, `age`, `type_pasture`, `protein_g`, `spo_cat`, `eke_square`.
#
# 2. Исключили нелинейность:
#
#     - `СПО` и `Удоя` преобразовали СПО в категориальный бинарный признак, использовав границу между кластерами (`spo_cat`).
#     - `ЕКЭ` и `Удоя` введя новый признак ЭКЕ в квадрате (`eke_square`).
#
# 3. Результат регрессии был следующим:
#
# - Коэффициент детерминации 0.79 [Увеличилось на 0.4]
#
#     - Т.е. в 79% случаев предсказание модели ближе к истине, чем среднее значение целевого признака.
#
# 4. Было необходимо:
#
# - Найти и добавить в модель дополнительный признак
#
# МОДЕЛЬ 3
#
# 1. Использовались такие входные признаки, как `breed_cow`, `type_pasture`, `breed_dad_cow`, `age`, `dad_name`, `spo_cat`, `eke_square`, `protein_g`.
#
# 2. Добавили новый признак `dad_name`
#
# 3. Результат регрессии был следующим:
#
# - Коэффициент детерминации: 0.80 (+0.01)
#
#     - Т.е. в 80% случаев предсказание модели ближе к истине, чем среднее значение целевого признака
#
# СРАВНЕНИЕ КАЧЕСТВА ТРЁХ МОДЕЛЕЙ
#
# **Наилучшие показатели у Модели 3**
#
# - Наивысший R²: 0.80
# - Наименьшее Среднее остатков: -9.75
# - Наименьшее Стандартное отклонение: 195.27
#
# **Оценка качества каждой модели по трём метрикам выявила лучшую модель:**
#
# - Модель 3:	R2 = 0.80	MSE = 37985	RMSE = 194	MAE = 150
#
# **Доверительный интервал**
#
# - Возможные ошибки предсказанных значений с вероятностью 95% лежат в интервале от -396 до 345.
#
# **Прогноз Удоя коров "ЭкоФермы"**
#
# Мы определили подходящих коров с учетом доверительного интервала, который показывает, что возможные ошибки предсказанных значений с вероятностью 95% лежат в интервале от -396 до 345.
#
# - Подходящие коровы с учетом доверительного интервала: 15 из 20
# - Индексы подходящих коров: [0, 3, 4, 5, 6, 7, 9, 10, 11, 12, 15, 16, 17, 18, 19]
#
# **Возможно ли ещё улучшить результаты регрессионной модели?**
#
# Маловата генеральная совокупность - можно увеличить количество данных, добавление новых признаков с линейной зависимостью
#
# ---
#
# <span style="color:violet"> **шаг 6** ОБУЧЕНИЕ МОДЕЛИ ЛОГИСТИЧЕСКОЙ РЕГРЕССИИ. ПРОГНОЗИРОВАНИЕ `Вкуса молока`
#
# ---
#
# МОДЕЛЬ 1
#
# - Accuracy: 0.64
# - Recall: 0.85
# - Precision: 0.65
#
# *Анализ логистической регрессии*
#
# - Критичнее всего **ошибка первого рода** False Positive (FP) — всего 43.
# - Чтобы увеличить точнось модели мы поработали с порогами разделения на классы, чтобы максимизировать метрику Precision.
#
# ПОДБОР ПОРОГА (для минимизации False Positive и максимизация Precision)
#
# ---
#
# **Порог = 0.82**
# - Precision = 1 (этот порог со 100% точностью исключит ошибки первого рода)
# - FP: 0 (нет ложных предсказаний)
# - Recall = 7.4% (распознает только наиболее вероятно качественное молоко)
#
# СРАВНЕНИЕ МЕТРИК  С ПОРОГОМ 0.5 и порогом 0.82
#
# - ACCURACY:  **0.64 → 0.45** (-0.19)
#
#     Общая точность снизилась на 19%, это закономерно ведь мы подныли порог
#
# - RECALL:    **0.85 → 0.075** (-0.78)
#
#     Раньше находил 85% вкусного молока, но каждый третий раз ошибался, теперь 7% находит вкусное молоко и не ошибается.
#
# - PRECISION: **0.65 → 1.0000** (+0.35)
#
#     Надежность положительных прогнозов достигла 100% - рост на 35% с предыдущего уровня
#
# ---
#
# **Порог = 0.68**
#
# - Precision: 85.4% (т.е. у одной из 6 коров, у которых предсказано вкусное молоко, будет не вкусное молоко)
#
# - FP: 6 (минимальное количество ложных предсказаний)
#
# - Recall: 37.2% (ниже, но все же находит 37% реальных объектов)
#
#
# СРАВНЕНИЕ МЕТРИК  С ПОРОГОМ 0.5 и порогом 0.68
#
# - ACCURACY:  **0.64 → 0.59** (-0.05)
#
#     Общая точность снизилась на 5%
#
# - RECALL:    **0.85 → 0.37** (-0.48)
#
#     Раньше находил 85% вкусного молока, но каждый третий раз ошибался, теперь 37% находит вкусное молоко и ошибается каждый шестой раз.
#
# - PRECISION: **0.65 → 0.85** (+0.20)
#
#     Надежность положительных прогнозов достигла 85% - рост на 20%
#
# ---
#
# ПРОГНОЗ ВКУСА МОЛОКА КОРОВ "ЭкоФермы"
#
# - С порогом 0.82 у всех коров не вкусное молоко (очень высокий порог для выборки в 20 коров)
# - Подходящие коровы с учетом вкуса: 5 из 20
# - Индексы подходящих коров: [0, 6, 9, 13, 16]
#
# ---
#
# <span style="color:violet"> **ИТОГ**
#
# РЕКОМЕНДАЦИИ ФЕРМЕРУ
#
# 1. Чтобы не понести убытки, фермеру не стоит покупать коров.
#
# 2. Если фермер готов рисковать (но не слишком):
#
# При пороге 0.68 точность отбора составила 85.4% (примерно 1 из 6 коров дает не вкусное молоко). Выявлено 5 коров с вкусным молоком.
#
# РИСКИ:
#
# - 5%, что корова имеет недостаточный удой и при этом 14.6% - вероятность отобрать корову с не вкусным молоком.
#
# Если фермер рисковый парень (но не слишком), то мы рекомендовали список коров с прогнозированным удоем более 6000 килограммов в год (с учетом доверительного интервала) и вкусное молоко. Четыре коровы с индексами 0, 6, 9, 16.
